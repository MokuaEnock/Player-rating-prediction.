# %% [markdown]
# <a href="https://www.kaggle.com/code/enockmokua/football-player-rating-prediction?scriptVersionId=97077976" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## 1. Defining the Question

# %% [markdown]
# ### Specifying the task

# %% [markdown]
# > We have tasked with predicting player rating based on variabl;es provided.

# %% [markdown]
# ###  Data Relevance

# %% [markdown]
# > The data was extracted from the popular electronic arts game FIFA 22 a football game (to my brothere and sisters in the U.S what you call soccer).

# %% [markdown]
# ## 2. Reading the Data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fifa-22-complete-player-dataset/players_fifa22.csv
# /kaggle/input/fifa-22-complete-player-dataset/teams_fifa22.csv

# %%
# libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import pylab 
import squarify
import missingno
import warnings
warnings.filterwarnings('ignore' )

# %% [markdown]
# Our player and teams data is provided on separate sheets and we will need to merge them for us to be able to conduct analysis and predict accurately.

# %%
#data
play = pd.read_csv('../input/fifa-22-complete-player-dataset/players_fifa22.csv')
team = pd.read_csv('../input/fifa-22-complete-player-dataset/teams_fifa22.csv')

# %% [markdown]
# ## 3. Checking the Data

# %% [markdown]
# #### 1. Players

# %%
# Determining the no. of records in our dataset
play.shape
# Out:
# (19260, 90)

# %%
# Previewing the top of our dataset
play.head(10)
# Out:
#        ID               Name                      FullName  Age  Height  \
# 0  158023           L. Messi                  Lionel Messi   34     170
# 1  188545     R. Lewandowski            Robert Lewandowski   32     185
# 2   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3  231747          K. Mbappé                 Kylian Mbappé   22     182
# 4  200389           J. Oblak                     Jan Oblak   28     188
# 5  192985       K. De Bruyne               Kevin De Bruyne   30     181
# 6  190871          Neymar Jr    Neymar da Silva Santos Jr.   29     175
# 7  215914           N. Kanté                  N'Golo Kanté   30     168
# 8  202126            H. Kane                    Harry Kane   27     188
# 9  192448      M. ter Stegen         Marc-André ter Stegen   29     187
#
#    Weight                                          PhotoUrl Nationality  \
# 0      72  https://cdn.sofifa.com/players/158/023/22_60.png   Argentina
# 1      81  https://cdn.sofifa.com/players/188/545/22_60.png      Poland
# 2      83  https://cdn.sofifa.com/players/020/801/22_60.png    Portugal
# 3      73  https://cdn.sofifa.com/players/231/747/22_60.png      France
# 4      87  https://cdn.sofifa.com/players/200/389/22_60.png    Slovenia
# 5      70  https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 6      68  https://cdn.sofifa.com/players/190/871/22_60.png      Brazil
# 7      70  https://cdn.sofifa.com/players/215/914/22_60.png      France
# 8      89  https://cdn.sofifa.com/players/202/126/22_60.png     England
# 9      85  https://cdn.sofifa.com/players/192/448/22_60.png     Germany
#
#    Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating CDMRating  \
# 0       93         93  ...        93        90        93        69        67
# 1       92         92  ...        87        83        87        67        69
# 2       91         91  ...        89        81        89        66        62
# 3       91         95  ...        92        84        92        70        66
# 4       91         93  ...        38        41        38        35        39
# 5       91         91  ...        91        91        91        82        83
# 6       91         91  ...        91        85        91        70        66
# 7       90         90  ...        82        85        82        88        90
# 8       90         90  ...        87        85        87        70        71
# 9       90         92  ...        42        48        42        36        44
#
#   RWBRating  LBRating  CBRating  RBRating GKRating
# 0        69        64        53        64       22
# 1        67        64        63        64       22
# 2        66        63        56        63       23
# 3        70        66        57        66       21
# 4        35        35        36        35       92
# 5        82        78        72        78       24
# 6        70        65        53        65       23
# 7        88        88        87        88       23
# 8        70        67        64        67       23
# 9        36        34        36        34       91
#
# [10 rows x 90 columns]

# %%
# Previewing the bottom of our dataset
play.tail(10)
# Out:
#            ID           Name        FullName  Age  Height  Weight  \
# 19250  257934      Guo Yunqi       Yunqi Guo   24     175      66
# 19251  261976    Lu Xianyong     Xianyong Lu   21     169      62
# 19252  257930        P. Kyum  Parmanjan Kyum   20     172      65
# 19253  260474   Kim Bong Soo    Bong Soo Kim   21     183      78
# 19254  255336     F. Emmings    Fred Emmings   17     195      95
# 19255  262759       S. Black   Stephen Black   19     180      75
# 19256  250978        Ma Zhen         Zhen Ma   23     196      85
# 19257  261985     Yang Haoyu      Haoyu Yang   20     183      77
# 19258  261977       He Siwei        Siwei He   20     174      69
# 19259  261932  Chen Guoliang   Guoliang Chen   22     186      70
#
#                                                PhotoUrl          Nationality  \
# 19250  https://cdn.sofifa.com/players/257/934/22_60.png             China PR
# 19251  https://cdn.sofifa.com/players/261/976/22_60.png             China PR
# 19252  https://cdn.sofifa.com/players/257/930/22_60.png             China PR
# 19253  https://cdn.sofifa.com/players/260/474/22_60.png       Korea Republic
# 19254  https://cdn.sofifa.com/players/255/336/22_60.png        United States
# 19255  https://cdn.sofifa.com/players/262/759/22_60.png  Republic of Ireland
# 19256  https://cdn.sofifa.com/players/250/978/22_60.png             China PR
# 19257  https://cdn.sofifa.com/players/261/985/22_60.png             China PR
# 19258  https://cdn.sofifa.com/players/261/977/22_60.png             China PR
# 19259  https://cdn.sofifa.com/players/261/932/22_60.png             China PR
#
#        Overall  Potential  ...  LMRating  CMRating  RMRating LWBRating  \
# 19250       48         53  ...        50        50        50        50
# 19251       48         55  ...        52        50        52        47
# 19252       48         53  ...        45        42        45        35
# 19253       48         57  ...        49        50        49        50
# 19254       48         73  ...        20        22        20        19
# 19255       48         62  ...        36        35        36        44
# 19256       48         52  ...        26        23        26        26
# 19257       48         55  ...        36        35        36        46
# 19258       48         58  ...        38        37        38        46
# 19259       48         53  ...        35        35        35        46
#
#       CDMRating RWBRating  LBRating  CBRating  RBRating GKRating
# 19250        50        50        50        49        50       17
# 19251        47        47        47        43        47       15
# 19252        32        35        34        31        34       17
# 19253        52        50        50        51        50       19
# 19254        23        19        18        22        18       49
# 19255        43        44        47        50        47       15
# 19256        23        26        26        26        26       49
# 19257        45        46        48        50        48       15
# 19258        45        46        49        50        49       17
# 19259        44        46        48        50        48       16
#
# [10 rows x 90 columns]

# %%
# Checking whether each column has an appropriate datatype
play.dtypes
# Out:
# ID            int64
# Name         object
# FullName     object
# Age           int64
# Height        int64
#               ...
# RWBRating     int64
# LBRating      int64
# CBRating      int64
# RBRating      int64
# GKRating      int64
# Length: 90, dtype: object

# %%
#checking the of columns 
play.columns
# Out:
# Index(['ID', 'Name', 'FullName', 'Age', 'Height', 'Weight', 'PhotoUrl',
#        'Nationality', 'Overall', 'Potential', 'Growth', 'TotalStats',
#        'BaseStats', 'Positions', 'BestPosition', 'Club', 'ValueEUR', 'WageEUR',
#        'ReleaseClause', 'ClubPosition', 'ContractUntil', 'ClubNumber',
#        'ClubJoined', 'OnLoad', 'NationalTeam', 'NationalPosition',
#        'NationalNumber', 'PreferredFoot', 'IntReputation', 'WeakFoot',
#        'SkillMoves', 'AttackingWorkRate', 'DefensiveWorkRate', 'PaceTotal',
#        'ShootingTotal', 'PassingTotal', 'DribblingTotal', 'DefendingTotal',
#        'PhysicalityTotal', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'STRating', 'LWRating', 'LFRating', 'CFRating', 'RFRating', 'RWRating',
#        'CAMRating', 'LMRating', 'CMRating', 'RMRating', 'LWBRating',
#        'CDMRating', 'RWBRating', 'LBRating', 'CBRating', 'RBRating',
#        'GKRating'],
#       dtype='object')

# %%
#getting general information about our dataset
play.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19260 entries, 0 to 19259
# Data columns (total 90 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 19260 non-null  int64
#  1   Name               19260 non-null  object
#  2   FullName           19260 non-null  object
#  3   Age                19260 non-null  int64
#  4   Height             19260 non-null  int64
#  5   Weight             19260 non-null  int64
#  6   PhotoUrl           19260 non-null  object
#  7   Nationality        19260 non-null  object
#  8   Overall            19260 non-null  int64
#  9   Potential          19260 non-null  int64
#  10  Growth             19260 non-null  int64
#  11  TotalStats         19260 non-null  int64
#  12  BaseStats          19260 non-null  int64
#  13  Positions          19260 non-null  object
#  14  BestPosition       19260 non-null  object
#  15  Club               19260 non-null  object
#  16  ValueEUR           19260 non-null  int64
#  17  WageEUR            19260 non-null  int64
#  18  ReleaseClause      19260 non-null  int64
#  19  ClubPosition       19184 non-null  object
#  20  ContractUntil      19184 non-null  float64
#  21  ClubNumber         19184 non-null  float64
#  22  ClubJoined         19260 non-null  int64
#  23  OnLoad             19260 non-null  bool
#  24  NationalTeam       19260 non-null  object
#  25  NationalPosition   757 non-null    object
#  26  NationalNumber     757 non-null    float64
#  27  PreferredFoot      19260 non-null  object
#  28  IntReputation      19260 non-null  int64
#  29  WeakFoot           19260 non-null  int64
#  30  SkillMoves         19260 non-null  int64
#  31  AttackingWorkRate  19260 non-null  object
#  32  DefensiveWorkRate  19260 non-null  object
#  33  PaceTotal          19260 non-null  int64
#  34  ShootingTotal      19260 non-null  int64
#  35  PassingTotal       19260 non-null  int64
#  36  DribblingTotal     19260 non-null  int64
#  37  DefendingTotal     19260 non-null  int64
#  38  PhysicalityTotal   19260 non-null  int64
#  39  Crossing           19260 non-null  int64
#  40  Finishing          19260 non-null  int64
#  41  HeadingAccuracy    19260 non-null  int64
#  42  ShortPassing       19260 non-null  int64
#  43  Volleys            19260 non-null  int64
#  44  Dribbling          19260 non-null  int64
#  45  Curve              19260 non-null  int64
#  46  FKAccuracy         19260 non-null  int64
#  47  LongPassing        19260 non-null  int64
#  48  BallControl        19260 non-null  int64
#  49  Acceleration       19260 non-null  int64
#  50  SprintSpeed        19260 non-null  int64
#  51  Agility            19260 non-null  int64
#  52  Reactions          19260 non-null  int64
#  53  Balance            19260 non-null  int64
#  54  ShotPower          19260 non-null  int64
#  55  Jumping            19260 non-null  int64
#  56  Stamina            19260 non-null  int64
#  57  Strength           19260 non-null  int64
#  58  LongShots          19260 non-null  int64
#  59  Aggression         19260 non-null  int64
#  60  Interceptions      19260 non-null  int64
#  61  Positioning        19260 non-null  int64
#  62  Vision             19260 non-null  int64
#  63  Penalties          19260 non-null  int64
#  64  Composure          19260 non-null  int64
#  65  Marking            19260 non-null  int64
#  66  StandingTackle     19260 non-null  int64
#  67  SlidingTackle      19260 non-null  int64
#  68  GKDiving           19260 non-null  int64
#  69  GKHandling         19260 non-null  int64
#  70  GKKicking          19260 non-null  int64
#  71  GKPositioning      19260 non-null  int64
#  72  GKReflexes         19260 non-null  int64
#  73  STRating           19260 non-null  int64
#  74  LWRating           19260 non-null  int64
#  75  LFRating           19260 non-null  int64
#  76  CFRating           19260 non-null  int64
#  77  RFRating           19260 non-null  int64
#  78  RWRating           19260 non-null  int64
#  79  CAMRating          19260 non-null  int64
#  80  LMRating           19260 non-null  int64
#  81  CMRating           19260 non-null  int64
#  82  RMRating           19260 non-null  int64
#  83  LWBRating          19260 non-null  int64
#  84  CDMRating          19260 non-null  int64
#  85  RWBRating          19260 non-null  int64
#  86  LBRating           19260 non-null  int64
#  87  CBRating           19260 non-null  int64
#  88  RBRating           19260 non-null  int64
#  89  GKRating           19260 non-null  int64
# dtypes: bool(1), float64(3), int64(73), object(13)
# memory usage: 13.1+ MB

# %% [markdown]
# #### 2. Team

# %%
# Determining the no. of records in our dataset
team.shape
# Out:
# (734, 14)

# %%
# Previewing the top of our dataset
team.head(10)
# Out:
#      ID                    Name                      League  LeagueId  \
# 0     1                 Arsenal  English Premier League (1)        13
# 1     2             Aston Villa  English Premier League (1)        13
# 2  1925               Brentford  English Premier League (1)        13
# 3  1808  Brighton & Hove Albion  English Premier League (1)        13
# 4  1796                 Burnley  English Premier League (1)        13
# 5     5                 Chelsea  English Premier League (1)        13
# 6  1799          Crystal Palace  English Premier League (1)        13
# 7     7                 Everton  English Premier League (1)        13
# 8     8            Leeds United  English Premier League (1)        13
# 9    95          Leicester City  English Premier League (1)        13
#
#    Overall  Attack  Midfield  Defence  TransferBudget  DomesticPrestige  \
# 0       79      83        81       77        77500000                 7
# 1       78      79        76       77        37500000                 4
# 2       73      73        74       73        18000000                 1
# 3       76      75        77       75        28000000                 2
# 4       76      76        76       77        22000000                 2
# 5       83      84        85       82        85000000                 8
# 6       76      77        76       74        30000000                 3
# 7       79      79        78       80        49000000                 6
# 8       76      78        78       76        32500000                 5
# 9       80      82        81       79        50000000                 7
#
#    IntPrestige  Players  StartingAverageAge  AllTeamAverageAge
# 0            7       33                25.1               23.2
# 1            3       31                24.7               23.3
# 2            1       33                24.7               23.4
# 3            1       33                26.9               23.5
# 4            1       33                28.6               26.6
# 5            8       33                27.8               24.8
# 6            2       33                27.6               25.3
# 7            5       33                27.3               25.7
# 8            2       31                26.4               22.7
# 9            6       33                27.4               25.3

# %%
# Previewing the bottom of our dataset
team.tail(10)
# Out:
#          ID                          Name                           League  \
# 724  101110         Club Atlético Peñarol   Uruguayan Primera División (1)
# 725  115535       Club Atlético Rentistas   Uruguayan Primera División (1)
# 726  111325     Club Nacional de Football   Uruguayan Primera División (1)
# 727  113143        Montevideo City Torque   Uruguayan Primera División (1)
# 728  110992         AC Mineros de Guayana  Venezuelan Primera División (1)
# 729  114611       Academia Puerto Cabello  Venezuelan Primera División (1)
# 730  112916            Aragua Fútbol Club  Venezuelan Primera División (1)
# 731  112853        Deportivo La Guaira FC  Venezuelan Primera División (1)
# 732  110990          Deportivo Táchira FC  Venezuelan Primera División (1)
# 733  112914  Metropolitanos de Caracas FC  Venezuelan Primera División (1)
#
#      LeagueId  Overall  Attack  Midfield  Defence  TransferBudget  \
# 724       338       69      67        70       65         4900000
# 725       338       65      64        65       64          500000
# 726       338       70      74        70       68         5400000
# 727       338       65      64        64       66         2700000
# 728      2019       61      58        61       61         1300000
# 729      2019       63      64        63       62         1500000
# 730      2019       63      63        62       61         1400000
# 731      2019       66      65        66       65         1200000
# 732      2019       63      65        63       63         1900000
# 733      2019       66      68        65       63         1500000
#
#      DomesticPrestige  IntPrestige  Players  StartingAverageAge  \
# 724                 8            6       26                27.1
# 725                 5            1       27                25.6
# 726                 9            6       22                26.9
# 727                 5            2       20                25.4
# 728                 5            3       24                26.1
# 729                 1            1       27                27.4
# 730                 3            3       28                27.4
# 731                 4            1       28                26.6
# 732                 6            4       27                27.7
# 733                 1            1       27                26.4
#
#      AllTeamAverageAge
# 724               25.4
# 725               24.4
# 726               26.4
# 727               24.4
# 728               23.1
# 729               24.5
# 730               25.5
# 731               25.6
# 732               26.1
# 733               25.0

# %%
# Checking whether each column has an appropriate datatype
team.dtypes
# Out:
# ID                      int64
# Name                   object
# League                 object
# LeagueId                int64
# Overall                 int64
# Attack                  int64
# Midfield                int64
# Defence                 int64
# TransferBudget          int64
# DomesticPrestige        int64
# IntPrestige             int64
# Players                 int64
# StartingAverageAge    float64
# AllTeamAverageAge     float64
# dtype: object

# %%
#getting the general information of our data
team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  734 non-null    int64
#  1   Name                734 non-null    object
#  2   League              734 non-null    object
#  3   LeagueId            734 non-null    int64
#  4   Overall             734 non-null    int64
#  5   Attack              734 non-null    int64
#  6   Midfield            734 non-null    int64
#  7   Defence             734 non-null    int64
#  8   TransferBudget      734 non-null    int64
#  9   DomesticPrestige    734 non-null    int64
#  10  IntPrestige         734 non-null    int64
#  11  Players             734 non-null    int64
#  12  StartingAverageAge  734 non-null    float64
#  13  AllTeamAverageAge   734 non-null    float64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 80.4+ KB

# %% [markdown]
# ## 4. External Data Source Validation

# %% [markdown]
# > For us to be sure that our dataset is valid and the results that we will be producing are valid we need to ensure that teh data we have can is valid we will be verifying our data against the international governering body of football, futsal and beach football (FIFA).
#
# > We can verify the data from the link here .[https://www.fifa.com/search-results?q=data]
#
# > We will also verify the data from electronic arts FIFa game here .[https://www.ea.com/games/fifa/fifa-22]

# %% [markdown]
# ### Setting the defaults

# %% [markdown]
# We will be setting the defaults for ouyr charts such as the fonts our charts will use and the colors.

# %%
#setting colors for our plots
colors = ['#7FB3D5', '#73C6B6', '#F0B27A', '#C39BD3', '#ABEBC6', '#F4D03F']
#setting the font, figsize and font size globally
plt.rcParams.update({'font.family':'Times New Roman'})
plt.rcParams.update({'font.size':15})
plt.rcParams.update({'font.weight': 'bold'})
plt.rcParams['figure.figsize'] = [10, 5]

# %%
#creating a function to calculate kurtosis and skewness of the data
def skew (column):
    from scipy import stats
    y = stats.skew(column).round(3)
    mean = column.mean().round(3)
    mode = column.mode().round(3)
    print('Skewness: ' + str(y))
    if y > 0:
        print('\nThe tail on the right side is greater than that on the left side the mean is greater than the mode: ')
    else:
        print('\nThe tail on the left side is greater than that on the right side the mode is greater than the mean: ')
    #checking on the Kurtosis 
    x = stats.kurtosis(column).round(3)
    print('\n Kurtosis: ' + str(x))
    if x == 0:
        print('\nThe data displays a normal distribution the data is mesokurtic.')
    elif x > 0:
        print('\nThe data is heavy tailed and has high degree of peakedness the data is leptokurtic.')
    else:
        print ('\nThe data is light tailed, hence it has a low degree of peakedness the data is platykurtic.')

# %% [markdown]
# ## 5. Tidying the Dataset

# %% [markdown]
# #### Players data

# %%
#checking for missing values
play.isna().any() == True
# Out:
# ID           False
# Name         False
# FullName     False
# Age          False
# Height       False
#              ...
# RWBRating    False
# LBRating     False
# CBRating     False
# RBRating     False
# GKRating     False
# Length: 90, dtype: bool

# %%
#selecting columns with atleast one missing values
p_alt = play.columns[play.isnull().sum() > 1]
p_alt1 = play[p_alt]
play1 = play.drop(columns = p_alt)
#adding the player id to the data 
p_alt2 = pd.concat([p_alt1, play[['ID']]], axis = 1)

# checcking the missing values
p_alt2.isnull().sum()
# Out:
# ClubPosition           76
# ContractUntil          76
# ClubNumber             76
# NationalPosition    18503
# NationalNumber      18503
# ID                      0
# dtype: int64

# %% [markdown]
# dropping the national position and national number because they contain more than 95% missing values

# %%
p_alt3 = p_alt2.drop(columns = ['NationalPosition', 'NationalNumber'])
p_alt3.head(5)
# Out:
#   ClubPosition  ContractUntil  ClubNumber      ID
# 0           RW         2023.0        30.0  158023
# 1           ST         2023.0         9.0  188545
# 2           ST         2023.0         7.0   20801
# 3           ST         2022.0         7.0  231747
# 4           GK         2023.0        13.0  200389

# %%
#filetring out the nan rows
nan_row = p_alt3[p_alt3['ClubPosition'].isna()]
nan_row.head(15)
# Out:
#      ClubPosition  ContractUntil  ClubNumber      ID
# 159           NaN            NaN         NaN  184087
# 480           NaN            NaN         NaN  197242
# 701           NaN            NaN         NaN  187607
# 1005          NaN            NaN         NaN  200094
# 1128          NaN            NaN         NaN  207554
# 1224          NaN            NaN         NaN  205211
# 1248          NaN            NaN         NaN  154950
# 1254          NaN            NaN         NaN  167575
# 1355          NaN            NaN         NaN  189060
# 2074          NaN            NaN         NaN  219409
# 2166          NaN            NaN         NaN  244700
# 2555          NaN            NaN         NaN  201884
# 2677          NaN            NaN         NaN  235973
# 2695          NaN            NaN         NaN  229585
# 2802          NaN            NaN         NaN  187533

# %%
#dropping the rows 
p_alt4 = p_alt3.dropna()
p_alt4.isnull().sum()
# Out:
# ClubPosition     0
# ContractUntil    0
# ClubNumber       0
# ID               0
# dtype: int64

# %%
play1
# Out:
#            ID               Name                      FullName  Age  Height  \
# 0      158023           L. Messi                  Lionel Messi   34     170
# 1      188545     R. Lewandowski            Robert Lewandowski   32     185
# 2       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3      231747          K. Mbappé                 Kylian Mbappé   22     182
# 4      200389           J. Oblak                     Jan Oblak   28     188
# ...       ...                ...                           ...  ...     ...
# 19255  262759           S. Black                 Stephen Black   19     180
# 19256  250978            Ma Zhen                       Zhen Ma   23     196
# 19257  261985         Yang Haoyu                    Haoyu Yang   20     183
# 19258  261977           He Siwei                      Siwei He   20     174
# 19259  261932      Chen Guoliang                 Guoliang Chen   22     186
#
#        Weight                                          PhotoUrl  \
# 0          72  https://cdn.sofifa.com/players/158/023/22_60.png
# 1          81  https://cdn.sofifa.com/players/188/545/22_60.png
# 2          83  https://cdn.sofifa.com/players/020/801/22_60.png
# 3          73  https://cdn.sofifa.com/players/231/747/22_60.png
# 4          87  https://cdn.sofifa.com/players/200/389/22_60.png
# ...       ...                                               ...
# 19255      75  https://cdn.sofifa.com/players/262/759/22_60.png
# 19256      85  https://cdn.sofifa.com/players/250/978/22_60.png
# 19257      77  https://cdn.sofifa.com/players/261/985/22_60.png
# 19258      69  https://cdn.sofifa.com/players/261/977/22_60.png
# 19259      70  https://cdn.sofifa.com/players/261/932/22_60.png
#
#                Nationality  Overall  Potential  ...  LMRating  CMRating  \
# 0                Argentina       93         93  ...        93        90
# 1                   Poland       92         92  ...        87        83
# 2                 Portugal       91         91  ...        89        81
# 3                   France       91         95  ...        92        84
# 4                 Slovenia       91         93  ...        38        41
# ...                    ...      ...        ...  ...       ...       ...
# 19255  Republic of Ireland       48         62  ...        36        35
# 19256             China PR       48         52  ...        26        23
# 19257             China PR       48         55  ...        36        35
# 19258             China PR       48         58  ...        38        37
# 19259             China PR       48         53  ...        35        35
#
#        RMRating LWBRating CDMRating RWBRating  LBRating  CBRating  RBRating  \
# 0            93        69        67        69        64        53        64
# 1            87        67        69        67        64        63        64
# 2            89        66        62        66        63        56        63
# 3            92        70        66        70        66        57        66
# 4            38        35        39        35        35        36        35
# ...         ...       ...       ...       ...       ...       ...       ...
# 19255        36        44        43        44        47        50        47
# 19256        26        26        23        26        26        26        26
# 19257        36        46        45        46        48        50        48
# 19258        38        46        45        46        49        50        49
# 19259        35        46        44        46        48        50        48
#
#        GKRating
# 0            22
# 1            22
# 2            23
# 3            21
# 4            92
# ...         ...
# 19255        15
# 19256        49
# 19257        15
# 19258        17
# 19259        16
#
# [19260 rows x 85 columns]

# %%
#filtering our joins to remain with rows that match the ID column only
play2 = play1[play1.ID.isin(p_alt4.ID)]
play2
# Out:
#            ID               Name                      FullName  Age  Height  \
# 0      158023           L. Messi                  Lionel Messi   34     170
# 1      188545     R. Lewandowski            Robert Lewandowski   32     185
# 2       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3      231747          K. Mbappé                 Kylian Mbappé   22     182
# 4      200389           J. Oblak                     Jan Oblak   28     188
# ...       ...                ...                           ...  ...     ...
# 19255  262759           S. Black                 Stephen Black   19     180
# 19256  250978            Ma Zhen                       Zhen Ma   23     196
# 19257  261985         Yang Haoyu                    Haoyu Yang   20     183
# 19258  261977           He Siwei                      Siwei He   20     174
# 19259  261932      Chen Guoliang                 Guoliang Chen   22     186
#
#        Weight                                          PhotoUrl  \
# 0          72  https://cdn.sofifa.com/players/158/023/22_60.png
# 1          81  https://cdn.sofifa.com/players/188/545/22_60.png
# 2          83  https://cdn.sofifa.com/players/020/801/22_60.png
# 3          73  https://cdn.sofifa.com/players/231/747/22_60.png
# 4          87  https://cdn.sofifa.com/players/200/389/22_60.png
# ...       ...                                               ...
# 19255      75  https://cdn.sofifa.com/players/262/759/22_60.png
# 19256      85  https://cdn.sofifa.com/players/250/978/22_60.png
# 19257      77  https://cdn.sofifa.com/players/261/985/22_60.png
# 19258      69  https://cdn.sofifa.com/players/261/977/22_60.png
# 19259      70  https://cdn.sofifa.com/players/261/932/22_60.png
#
#                Nationality  Overall  Potential  ...  LMRating  CMRating  \
# 0                Argentina       93         93  ...        93        90
# 1                   Poland       92         92  ...        87        83
# 2                 Portugal       91         91  ...        89        81
# 3                   France       91         95  ...        92        84
# 4                 Slovenia       91         93  ...        38        41
# ...                    ...      ...        ...  ...       ...       ...
# 19255  Republic of Ireland       48         62  ...        36        35
# 19256             China PR       48         52  ...        26        23
# 19257             China PR       48         55  ...        36        35
# 19258             China PR       48         58  ...        38        37
# 19259             China PR       48         53  ...        35        35
#
#        RMRating LWBRating CDMRating RWBRating  LBRating  CBRating  RBRating  \
# 0            93        69        67        69        64        53        64
# 1            87        67        69        67        64        63        64
# 2            89        66        62        66        63        56        63
# 3            92        70        66        70        66        57        66
# 4            38        35        39        35        35        36        35
# ...         ...       ...       ...       ...       ...       ...       ...
# 19255        36        44        43        44        47        50        47
# 19256        26        26        23        26        26        26        26
# 19257        36        46        45        46        48        50        48
# 19258        38        46        45        46        49        50        49
# 19259        35        46        44        46        48        50        48
#
#        GKRating
# 0            22
# 1            22
# 2            23
# 3            21
# 4            92
# ...         ...
# 19255        15
# 19256        49
# 19257        15
# 19258        17
# 19259        16
#
# [19184 rows x 85 columns]

# %% [markdown]
# We will drop the photourl since it contains a link to the players mugshots this is unique for every player hence we will drop it.

# %%
play3 = play2.drop(columns = ['PhotoUrl'])
play3.head(10)
# Out:
#        ID               Name                      FullName  Age  Height  \
# 0  158023           L. Messi                  Lionel Messi   34     170
# 1  188545     R. Lewandowski            Robert Lewandowski   32     185
# 2   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3  231747          K. Mbappé                 Kylian Mbappé   22     182
# 4  200389           J. Oblak                     Jan Oblak   28     188
# 5  192985       K. De Bruyne               Kevin De Bruyne   30     181
# 6  190871          Neymar Jr    Neymar da Silva Santos Jr.   29     175
# 7  215914           N. Kanté                  N'Golo Kanté   30     168
# 8  202126            H. Kane                    Harry Kane   27     188
# 9  192448      M. ter Stegen         Marc-André ter Stegen   29     187
#
#    Weight Nationality  Overall  Potential  Growth  ...  LMRating  CMRating  \
# 0      72   Argentina       93         93       0  ...        93        90
# 1      81      Poland       92         92       0  ...        87        83
# 2      83    Portugal       91         91       0  ...        89        81
# 3      73      France       91         95       4  ...        92        84
# 4      87    Slovenia       91         93       2  ...        38        41
# 5      70     Belgium       91         91       0  ...        91        91
# 6      68      Brazil       91         91       0  ...        91        85
# 7      70      France       90         90       0  ...        82        85
# 8      89     England       90         90       0  ...        87        85
# 9      85     Germany       90         92       2  ...        42        48
#
#   RMRating LWBRating CDMRating  RWBRating  LBRating  CBRating  RBRating  \
# 0       93        69        67         69        64        53        64
# 1       87        67        69         67        64        63        64
# 2       89        66        62         66        63        56        63
# 3       92        70        66         70        66        57        66
# 4       38        35        39         35        35        36        35
# 5       91        82        83         82        78        72        78
# 6       91        70        66         70        65        53        65
# 7       82        88        90         88        88        87        88
# 8       87        70        71         70        67        64        67
# 9       42        36        44         36        34        36        34
#
#    GKRating
# 0        22
# 1        22
# 2        23
# 3        21
# 4        92
# 5        24
# 6        23
# 7        23
# 8        23
# 9        91
#
# [10 rows x 84 columns]

# %% [markdown]
# #### Team data

# %%
#checking for null values 
team.isnull().sum()
# Out:
# ID                    0
# Name                  0
# League                0
# LeagueId              0
# Overall               0
# Attack                0
# Midfield              0
# Defence               0
# TransferBudget        0
# DomesticPrestige      0
# IntPrestige           0
# Players               0
# StartingAverageAge    0
# AllTeamAverageAge     0
# dtype: int64

# %%
#previewing the top of the dataset
team.head(10)
# Out:
#      ID                    Name                      League  LeagueId  \
# 0     1                 Arsenal  English Premier League (1)        13
# 1     2             Aston Villa  English Premier League (1)        13
# 2  1925               Brentford  English Premier League (1)        13
# 3  1808  Brighton & Hove Albion  English Premier League (1)        13
# 4  1796                 Burnley  English Premier League (1)        13
# 5     5                 Chelsea  English Premier League (1)        13
# 6  1799          Crystal Palace  English Premier League (1)        13
# 7     7                 Everton  English Premier League (1)        13
# 8     8            Leeds United  English Premier League (1)        13
# 9    95          Leicester City  English Premier League (1)        13
#
#    Overall  Attack  Midfield  Defence  TransferBudget  DomesticPrestige  \
# 0       79      83        81       77        77500000                 7
# 1       78      79        76       77        37500000                 4
# 2       73      73        74       73        18000000                 1
# 3       76      75        77       75        28000000                 2
# 4       76      76        76       77        22000000                 2
# 5       83      84        85       82        85000000                 8
# 6       76      77        76       74        30000000                 3
# 7       79      79        78       80        49000000                 6
# 8       76      78        78       76        32500000                 5
# 9       80      82        81       79        50000000                 7
#
#    IntPrestige  Players  StartingAverageAge  AllTeamAverageAge
# 0            7       33                25.1               23.2
# 1            3       31                24.7               23.3
# 2            1       33                24.7               23.4
# 3            1       33                26.9               23.5
# 4            1       33                28.6               26.6
# 5            8       33                27.8               24.8
# 6            2       33                27.6               25.3
# 7            5       33                27.3               25.7
# 8            2       31                26.4               22.7
# 9            6       33                27.4               25.3

# %% [markdown]
# Since there are no major probllems with the teams data set we will go on and merge the data into one dataset that contains all the information.

# %% [markdown]
# #### Merging the data

# %%
#preparing the data for merging
team1 = team.rename(columns={"Name":"Club", 'Overall' : 'Team_Overall'})
play4 = play3.drop(columns = ['ID', 'FullName'])
team2 = team1.drop(columns = ['ID'])
#merging the data
al = pd.merge(play4, team2,how='left', on='Club')
al.head(10)
# Out:
#                 Name  Age  Height  Weight Nationality  Overall  Potential  \
# 0           L. Messi   34     170      72   Argentina       93         93
# 1     R. Lewandowski   32     185      81      Poland       92         92
# 2  Cristiano Ronaldo   36     187      83    Portugal       91         91
# 3          K. Mbappé   22     182      73      France       91         95
# 4           J. Oblak   28     188      87    Slovenia       91         93
# 5       K. De Bruyne   30     181      70     Belgium       91         91
# 6          Neymar Jr   29     175      68      Brazil       91         91
# 7           N. Kanté   30     168      70      France       90         90
# 8            H. Kane   27     188      89     England       90         90
# 9      M. ter Stegen   29     187      85     Germany       90         92
#
#    Growth  TotalStats  BaseStats  ... Team_Overall Attack Midfield  Defence  \
# 0       0        2219        462  ...         86.0   89.0     83.0     85.0
# 1       0        2212        460  ...         84.0   92.0     85.0     81.0
# 2       0        2208        457  ...         84.0   85.0     84.0     83.0
# 3       4        2175        470  ...         86.0   89.0     83.0     85.0
# 4       2        1413        489  ...         84.0   84.0     83.0     83.0
# 5       0        2304        485  ...         85.0   85.0     85.0     86.0
# 6       0        2183        454  ...         86.0   89.0     83.0     85.0
# 7       0        2179        470  ...         83.0   84.0     85.0     82.0
# 8       0        2205        456  ...         82.0   86.0     80.0     80.0
# 9       2        1444        484  ...         83.0   85.0     84.0     80.0
#
#    TransferBudget  DomesticPrestige  IntPrestige  Players StartingAverageAge  \
# 0     160000000.0              10.0          9.0     33.0               28.1
# 1     100000000.0              10.0         10.0     28.0               26.6
# 2     175000000.0               9.0          8.0     33.0               26.6
# 3     160000000.0              10.0          9.0     33.0               28.1
# 4      68600000.0               9.0          9.0     32.0               28.1
# 5     176000000.0              10.0         10.0     33.0               27.0
# 6     160000000.0              10.0          9.0     33.0               28.1
# 7      85000000.0               8.0          8.0     33.0               27.8
# 8      72500000.0               8.0          7.0     33.0               25.9
# 9     130000000.0              10.0         10.0     33.0               26.6
#
#   AllTeamAverageAge
# 0              25.9
# 1              24.8
# 2              25.9
# 3              25.9
# 4              25.2
# 5              23.9
# 6              25.9
# 7              24.8
# 8              23.0
# 9              24.1
#
# [10 rows x 94 columns]

# %%
#selecting columns with atleast one missing values
al1 = al.columns[al.isnull().sum() > 1]
al2 = al[al1]
al2.isnull().sum()
# Out:
# League                28
# LeagueId              28
# Team_Overall          28
# Attack                28
# Midfield              28
# Defence               28
# TransferBudget        28
# DomesticPrestige      28
# IntPrestige           28
# Players               28
# StartingAverageAge    28
# AllTeamAverageAge     28
# dtype: int64

# %% [markdown]
# Since the columns contain only 28 missing values each out of the 18,000 records we will drop the missing values.

# %%
al3 = (al.dropna()).reset_index()
al3
# Out:
#        index               Name  Age  Height  Weight          Nationality  \
# 0          0           L. Messi   34     170      72            Argentina
# 1          1     R. Lewandowski   32     185      81               Poland
# 2          2  Cristiano Ronaldo   36     187      83             Portugal
# 3          3          K. Mbappé   22     182      73               France
# 4          4           J. Oblak   28     188      87             Slovenia
# ...      ...                ...  ...     ...     ...                  ...
# 19151  19179           S. Black   19     180      75  Republic of Ireland
# 19152  19180            Ma Zhen   23     196      85             China PR
# 19153  19181         Yang Haoyu   20     183      77             China PR
# 19154  19182           He Siwei   20     174      69             China PR
# 19155  19183      Chen Guoliang   22     186      70             China PR
#
#        Overall  Potential  Growth  TotalStats  ...  Team_Overall Attack  \
# 0           93         93       0        2219  ...          86.0   89.0
# 1           92         92       0        2212  ...          84.0   92.0
# 2           91         91       0        2208  ...          84.0   85.0
# 3           91         95       4        2175  ...          86.0   89.0
# 4           91         93       2        1413  ...          84.0   84.0
# ...        ...        ...     ...         ...  ...           ...    ...
# 19151       48         62      14        1160  ...          58.0   59.0
# 19152       48         52       4         964  ...          68.0   71.0
# 19153       48         55       7        1166  ...          63.0   75.0
# 19154       48         58      10        1198  ...          59.0   66.0
# 19155       48         53       5        1179  ...          66.0   73.0
#
#       Midfield Defence  TransferBudget  DomesticPrestige  IntPrestige  \
# 0         83.0    85.0     160000000.0              10.0          9.0
# 1         85.0    81.0     100000000.0              10.0         10.0
# 2         84.0    83.0     175000000.0               9.0          8.0
# 3         83.0    85.0     160000000.0              10.0          9.0
# 4         83.0    83.0      68600000.0               9.0          9.0
# ...        ...     ...             ...               ...          ...
# 19151     58.0    59.0        500000.0               2.0          1.0
# 19152     69.0    64.0       5000000.0               5.0          3.0
# 19153     61.0    63.0       5700000.0               5.0          1.0
# 19154     57.0    56.0       3500000.0               2.0          1.0
# 19155     67.0    61.0       5100000.0               3.0          1.0
#
#        Players  StartingAverageAge AllTeamAverageAge
# 0         33.0                28.1              25.9
# 1         28.0                26.6              24.8
# 2         33.0                26.6              25.9
# 3         33.0                28.1              25.9
# 4         32.0                28.1              25.2
# ...        ...                 ...               ...
# 19151     26.0                27.0              25.1
# 19152     28.0                31.4              29.9
# 19153     28.0                28.1              25.3
# 19154     28.0                29.6              26.6
# 19155     27.0                28.8              26.9
#
# [19156 rows x 95 columns]

# %% [markdown]
# Having cleaned our data effectively the data is ready for exploratory data analysis.

# %% [markdown]
# For the purpose of simplifying our visualization and prediction we are going to break down our data acording to the players best position/teh preffered player position this will enable our visualization and models to focus on the players strong points only.
# We will break down our data according to the following player positions, RW, ST, GK, CM, LW, CDM, LM, CF, CB, CAM, LB, RB, RM, LWB and RWB
# The following is a sample football formation with the positions stated above

# %% [markdown]
# ![Football_positions.png](attachment:Football_positions.png)

# %%
#exporting our data so as to conduct data visualization in tableau
gfg_csv_data = al3.to_csv('Fifa22r.csv', index = False)
print(r'"C:\Users\mokua\Desktop\Github projects\Fifa 22"', gfg_csv_data)
# Out:
# "C:\Users\mokua\Desktop\Github projects\Fifa 22" None

# %% [markdown]
# ## 6. Exploratory Analysis

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1653074739837' style='position: relative'><noscript><a href='#'><img alt='Story 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;FI&#47;FIFA22_16530745070990&#47;Story1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='views&#47;FIFA22_16530745070990&#47;Story1?:language=en-US&amp;:embed=true&amp;publish=yes' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;FI&#47;FIFA22_16530745070990&#47;Story1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1653074739837');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='1016px';vizElement.style.height='991px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1653074739837' style='position: relative'><noscript><a href='#'><img alt='Story 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;FI&#47;FIFA22_16530745070990&#47;Story1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='views&#47;FIFA22_16530745070990&#47;Story1?:language=en-US&amp;:embed=true&amp;publish=yes' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;FI&#47;FIFA22_16530745070990&#47;Story1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1653074739837');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='1016px';vizElement.style.height='991px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# ## 7. Feature engineering

# %% [markdown]
# Our first step will be dropping unique identifiers from our data whether they are for the players or the clubs they play for or the league they are in. From our column swe have 2 columns signifying the positions the player can play one is **positions** which includes all the possible positions that a player can play and the other is **best_position** which is the best position a player can play, we will be dropping **positions** to remain with only the best possible position of a player.

# %%
al4 = al3.drop( columns = ['LeagueId', 'Name', 'Positions']).set_index('index')

# %% [markdown]
# ### Categorical encoding

# %% [markdown]
# Transformation of any categorical features in the data will be important to facilitate feature engineering and modelling.

# %%
#separating our data into the predictors, position and target variable
al4_x = al4.drop( columns = ['BestPosition', 'Overall'])
al4_y = al4[['Overall']]
al4_p = al4[['BestPosition']]

#selecting non-numeric columns from our predictors
al4o = al4_x.select_dtypes(include=['object'])
al4o.head(6)
# Out:
#       Nationality                 Club NationalTeam PreferredFoot  \
# index
# 0       Argentina  Paris Saint-Germain    Argentina          Left
# 1          Poland    FC Bayern München       Poland         Right
# 2        Portugal    Manchester United     Portugal         Right
# 3          France  Paris Saint-Germain       France         Right
# 4        Slovenia   Atlético de Madrid  Not in team         Right
# 5         Belgium      Manchester City      Belgium         Right
#
#       AttackingWorkRate DefensiveWorkRate                      League
# index
# 0                Medium               Low          French Ligue 1 (1)
# 1                  High            Medium    German 1. Bundesliga (1)
# 2                  High               Low  English Premier League (1)
# 3                  High               Low          French Ligue 1 (1)
# 4                Medium            Medium  Spain Primera Division (1)
# 5                  High              High  English Premier League (1)

# %% [markdown]
# From our features above we have ordinal and nominal variables.
# > **Ordinal** - These are attacking work rate and defensive work rate since this categories can be ranked we will apply ordinal encoding here.
# > **Nominal** - These are the variable in our data that do not assume ordering from our data these include nationality, club, national team, preferred foot and league
#
# For the ordinal features we will assign numeric values based on our intution
# > high > medium >low

# %%
ordinal = al4o[['AttackingWorkRate', 'DefensiveWorkRate']]
#transforming
ordinal['AttackingWorkRate'] = ordinal['AttackingWorkRate'].replace(['Medium','High', 'Low'],[2, 3, 1])
ordinal['DefensiveWorkRate'] = ordinal['DefensiveWorkRate'].replace(['Medium','High', 'Low'],[2, 3, 1])

# %% [markdown]
# For the nominal features we will aplly target encoding specifically mean encoding to our columns

# %%
#selecting nominal features
nominal = al4o[['Nationality', 'Club', 'NationalTeam', 'PreferredFoot', 'League']]

from category_encoders import MEstimateEncoder

# Create the encoder instance. Choose m to control noise.
encoder = MEstimateEncoder(cols = ['Nationality', 'Club', 'NationalTeam', 'PreferredFoot', 'League'] , m=5.0)

# Fit the encoder on the encoding split.
encoder.fit(nominal, al4_y)

# Encode the Zipcode column to create the final training data
n_x = encoder.transform(nominal)

#concating the datasets
m = pd.concat([n_x, ordinal], axis = 1)
n = pd.concat([al4_p, al4_y], axis = 1)
l = pd.concat([m, n], axis = 1)

#concat data with the rest of the data
ab = al4.drop(columns = l.columns)
al5 = pd.concat([ab, l], axis = 1)
al5.shape
# Out:
# (19156, 91)

# %% [markdown]
# We will group the data based on the positions of the players

# %%
# splitting dataframe by groups
grouped = al5.groupby(al5.BestPosition)
RW = grouped.get_group("RW")
ST = grouped.get_group("ST")
GK = grouped.get_group("GK")
CM = grouped.get_group("CM")
LW = grouped.get_group("LW")
CDM = grouped.get_group("CDM")
LM = grouped.get_group("LM")
CF = grouped.get_group("CF")
CB = grouped.get_group("CB")
CAM = grouped.get_group("CAM")
LB = grouped.get_group("LB")
RB = grouped.get_group("RB")
RM = grouped.get_group("RM")
LWB = grouped.get_group("LWB")
RWB = grouped.get_group("RWB")

# %% [markdown]
# Having created groups for our players positions we will group them based on the player position similarity defenders midfielders, attackers and goalkeepers will be in individual categories.
# - group_1 = goalkeeper
# - group_2 = defenders = lb, lwb, cb, rb, rwb
# - group_3 = midfielders = cam, cm, rm, lm, cdm
# - group_4 = attackers = cf, st, lw, rw

# %%
#creating the groups
g1 = GK
g2 = pd.concat([LB, RB, CB, RWB, LWB])
g3 = pd.concat([RM, LM, CAM, CM, CDM])
g4 = pd.concat([CF, ST, LW, RW])

# %% [markdown]
# Since we have not decided which model we will us ein training we will employ the mutual information, a feature measuirng the assopciations between the independet variables and the features in our data.

# %% [markdown]
# #### Group 1

# %%
#choosing our target variable from the data 
g1_X = g1.drop(columns = ['Overall', 'BestPosition'])
g1_y = g1[['Overall']]

# %%
#creating discrete features
discrete_features = g1_X.dtypes == int

#applying the mutual information we will choose the mutual info regression since our target variable is continous
from sklearn.feature_selection import mutual_info_regression
def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores
mi_scores = make_mi_scores(g1_X, g1_y, discrete_features)
mi_scores.head(60)
# Out:
# GKRating            2.843334
# ValueEUR            1.506824
# BaseStats           1.436496
# PaceTotal           1.235111
# GKDiving            1.235111
# GKReflexes          1.229616
# DribblingTotal      1.229616
# PhysicalityTotal    1.219565
# GKPositioning       1.219565
# GKHandling          1.114890
# ShootingTotal       1.114890
# Potential           0.913430
# ReleaseClause       0.911224
# Reactions           0.775503
# PassingTotal        0.648687
# GKKicking           0.648687
# ShotPower           0.632206
# WageEUR             0.544028
# TotalStats          0.522924
# STRating            0.440324
# LFRating            0.374941
# CFRating            0.374941
# RFRating            0.374941
# CAMRating           0.330570
# LWBRating           0.330240
# RWBRating           0.330240
# RMRating            0.327539
# LMRating            0.327539
# CDMRating           0.326804
# LBRating            0.311743
# RBRating            0.311743
# CBRating            0.304226
# LWRating            0.303634
# RWRating            0.303634
# CMRating            0.292844
# Composure           0.288182
# Growth              0.271737
# Club                0.256900
# League              0.242929
# Team_Overall        0.234761
# Age                 0.216012
# Defence             0.210538
# Midfield            0.197661
# Attack              0.170260
# Acceleration        0.158209
# SprintSpeed         0.147698
# Nationality         0.146468
# Vision              0.140445
# DefendingTotal      0.139197
# BallControl         0.135543
# Dribbling           0.127329
# TransferBudget      0.127106
# IntReputation       0.125495
# Marking             0.124384
# Agility             0.122385
# Jumping             0.120059
# LongShots           0.119018
# Volleys             0.116952
# Interceptions       0.116270
# ShortPassing        0.115224
# Name: MI Scores, dtype: float64

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")
plt.figure(dpi=70, figsize=(10, 30))
plot_mi_scores(mi_scores)

# %% [markdown]
# We will choose faetures with an mutual information score of more than 0.5

# %%
m1_scores = pd.DataFrame(mi_scores).reset_index()
m2_scores = m1_scores.rename(columns = {'index' : 'feature'})
m3_score = m2_scores[m2_scores['MI Scores'] >= 0.5]
#selecting the features
g1_x1 = g1_X[m3_score.feature.unique()]

#checking on the correlation of our variables
g1_x1.corr()
# Out:
#                   GKRating  ValueEUR  BaseStats  PaceTotal  GKDiving  \
# GKRating          1.000000  0.496861   0.967638   0.953642  0.953642
# ValueEUR          0.496861  1.000000   0.460356   0.467500  0.467500
# BaseStats         0.967638  0.460356   1.000000   0.928242  0.928242
# PaceTotal         0.953642  0.467500   0.928242   1.000000  1.000000
# GKDiving          0.953642  0.467500   0.928242   1.000000  1.000000
# GKReflexes        0.954430  0.463145   0.927630   0.919479  0.919479
# DribblingTotal    0.954430  0.463145   0.927630   0.919479  0.919479
# PhysicalityTotal  0.944314  0.430243   0.922407   0.869245  0.869245
# GKPositioning     0.944314  0.430243   0.922407   0.869245  0.869245
# GKHandling        0.935310  0.467344   0.908230   0.865808  0.865808
# ShootingTotal     0.935310  0.467344   0.908230   0.865808  0.865808
# Potential         0.722566  0.494729   0.656993   0.696265  0.696265
# ReleaseClause     0.469092  0.982659   0.433170   0.439329  0.439329
# Reactions         0.851178  0.386540   0.820139   0.779681  0.779681
# PassingTotal      0.818527  0.402954   0.850685   0.759194  0.759194
# GKKicking         0.818527  0.402954   0.850685   0.759194  0.759194
# ShotPower         0.817883  0.402483   0.849980   0.758652  0.758652
# WageEUR           0.579039  0.803157   0.554500   0.550768  0.550768
# TotalStats        0.793150  0.359458   0.875123   0.748839  0.748839
#
#                   GKReflexes  DribblingTotal  PhysicalityTotal  GKPositioning  \
# GKRating            0.954430        0.954430          0.944314       0.944314
# ValueEUR            0.463145        0.463145          0.430243       0.430243
# BaseStats           0.927630        0.927630          0.922407       0.922407
# PaceTotal           0.919479        0.919479          0.869245       0.869245
# GKDiving            0.919479        0.919479          0.869245       0.869245
# GKReflexes          1.000000        1.000000          0.869855       0.869855
# DribblingTotal      1.000000        1.000000          0.869855       0.869855
# PhysicalityTotal    0.869855        0.869855          1.000000       1.000000
# GKPositioning       0.869855        0.869855          1.000000       1.000000
# GKHandling          0.854767        0.854767          0.887368       0.887368
# ShootingTotal       0.854767        0.854767          0.887368       0.887368
# Potential           0.702178        0.702178          0.631379       0.631379
# ReleaseClause       0.435519        0.435519          0.404966       0.404966
# Reactions           0.784650        0.784650          0.772963       0.772963
# PassingTotal        0.759854        0.759854          0.775810       0.775810
# GKKicking           0.759854        0.759854          0.775810       0.775810
# ShotPower           0.759601        0.759601          0.775409       0.775409
# WageEUR             0.547210        0.547210          0.517035       0.517035
# TotalStats          0.747712        0.747712          0.757318       0.757318
#
#                   GKHandling  ShootingTotal  Potential  ReleaseClause  \
# GKRating            0.935310       0.935310   0.722566       0.469092
# ValueEUR            0.467344       0.467344   0.494729       0.982659
# BaseStats           0.908230       0.908230   0.656993       0.433170
# PaceTotal           0.865808       0.865808   0.696265       0.439329
# GKDiving            0.865808       0.865808   0.696265       0.439329
# GKReflexes          0.854767       0.854767   0.702178       0.435519
# DribblingTotal      0.854767       0.854767   0.702178       0.435519
# PhysicalityTotal    0.887368       0.887368   0.631379       0.404966
# GKPositioning       0.887368       0.887368   0.631379       0.404966
# GKHandling          1.000000       1.000000   0.666251       0.442379
# ShootingTotal       1.000000       1.000000   0.666251       0.442379
# Potential           0.666251       0.666251   1.000000       0.471218
# ReleaseClause       0.442379       0.442379   0.471218       1.000000
# Reactions           0.743121       0.743121   0.522301       0.363772
# PassingTotal        0.777569       0.777569   0.581067       0.380338
# GKKicking           0.777569       0.777569   0.581067       0.380338
# ShotPower           0.776406       0.776406   0.579672       0.380199
# WageEUR             0.550639       0.550639   0.506149       0.780650
# TotalStats          0.726887       0.726887   0.428538       0.337580
#
#                   Reactions  PassingTotal  GKKicking  ShotPower   WageEUR  \
# GKRating           0.851178      0.818527   0.818527   0.817883  0.579039
# ValueEUR           0.386540      0.402954   0.402954   0.402483  0.803157
# BaseStats          0.820139      0.850685   0.850685   0.849980  0.554500
# PaceTotal          0.779681      0.759194   0.759194   0.758652  0.550768
# GKDiving           0.779681      0.759194   0.759194   0.758652  0.550768
# GKReflexes         0.784650      0.759854   0.759854   0.759601  0.547210
# DribblingTotal     0.784650      0.759854   0.759854   0.759601  0.547210
# PhysicalityTotal   0.772963      0.775810   0.775810   0.775409  0.517035
# GKPositioning      0.772963      0.775810   0.775810   0.775409  0.517035
# GKHandling         0.743121      0.777569   0.777569   0.776406  0.550639
# ShootingTotal      0.743121      0.777569   0.777569   0.776406  0.550639
# Potential          0.522301      0.581067   0.581067   0.579672  0.506149
# ReleaseClause      0.363772      0.380338   0.380338   0.380199  0.780650
# Reactions          1.000000      0.661932   0.661932   0.661765  0.471109
# PassingTotal       0.661932      1.000000   1.000000   0.998720  0.472136
# GKKicking          0.661932      1.000000   1.000000   0.998720  0.472136
# ShotPower          0.661765      0.998720   0.998720   1.000000  0.471909
# WageEUR            0.471109      0.472136   0.472136   0.471909  1.000000
# TotalStats         0.772024      0.724595   0.724595   0.723728  0.460451
#
#                   TotalStats
# GKRating            0.793150
# ValueEUR            0.359458
# BaseStats           0.875123
# PaceTotal           0.748839
# GKDiving            0.748839
# GKReflexes          0.747712
# DribblingTotal      0.747712
# PhysicalityTotal    0.757318
# GKPositioning       0.757318
# GKHandling          0.726887
# ShootingTotal       0.726887
# Potential           0.428538
# ReleaseClause       0.337580
# Reactions           0.772024
# PassingTotal        0.724595
# GKKicking           0.724595
# ShotPower           0.723728
# WageEUR             0.460451
# TotalStats          1.000000

# %% [markdown]
# #### Multicollinearity

# %% [markdown]
# Multicollinearity occurs when there is two or more variables in a multi regression modle that are highly corelated, when this occurs we might have difficulty in distinguishing between their individual effects on the dependent variable. The ridge rgeression model is used to analysze multiple regression data that is highly correlated. We will be detecting multicollinearity using variamce inflation factors given by **VIF = 1/(1 - Rsquared)** where R-squared is the coefficient of determination.

# %%
#selecting the features
goal1 = g1_x1.copy()

# %% [markdown]
# We will first compute the correlation coeficients of the data

# %%
# set figure size
plt.figure(figsize=(10,7))

# Generate a mask to onlyshow the bottom triangle
mask = np.triu(np.ones_like(goal1.corr(), dtype=bool))
# generate heatmap
sb.heatmap(goal1.corr(), annot=True, mask=mask, vmin=-1, vmax=1 ,cmap="YlGnBu", center = 0)
plt.title('Correlation Coefficient Of Predictors')
plt.show()

# %% [markdown]
# The correlation coefficient of most predictors is above 0.8 which shows very high multicollinearity in the predictors.

# %%
#plotting a cluster map
sb.clustermap(goal1.corr(), figsize=(20,20), cmap = "YlGnBu")

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
#creating a function to test for vif cores  
def compute_vif(considered_features):
    X = considered_features
    # the calculation of variance inflation requires a constant
    X['intercept'] = 1
    # create dataframe to store vif values
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']
    return vif

#checking the vif scores for our data
y = compute_vif(goal1)
goal1.drop(columns = ['intercept'], inplace = True)
y
# Out:
#             Variable         VIF
# 0           GKRating  273.747011
# 1           ValueEUR   32.893035
# 2          BaseStats   44.482996
# 3          PaceTotal         inf
# 4           GKDiving         inf
# 5         GKReflexes         inf
# 6     DribblingTotal         inf
# 7   PhysicalityTotal         inf
# 8      GKPositioning         inf
# 9         GKHandling         inf
# 10     ShootingTotal         inf
# 11         Potential    3.014309
# 12     ReleaseClause   29.642199
# 13         Reactions    9.232833
# 14      PassingTotal         inf
# 15         GKKicking         inf
# 16         ShotPower  392.571728
# 17           WageEUR    3.245122
# 18        TotalStats    7.018866

# %% [markdown]
# From our visualizations above we have seen that our predictors are higly corellated dropping some of the higly correlated features will lead to us loosing a lot of information from the data about 90% since we will remain with only three columns.

# %%
#describing our features
goal1.describe()
# Out:
#           GKRating      ValueEUR    BaseStats    PaceTotal     GKDiving  \
# count  2113.000000  2.113000e+03  2113.000000  2113.000000  2113.000000
# mean     65.108377  1.945269e+06   355.100805    65.001893    65.001893
# std       7.349570  6.682800e+06    41.895294     7.486098     7.486098
# min      49.000000  9.000000e+03   260.000000    42.000000    42.000000
# 25%      60.000000  2.500000e+05   325.000000    60.000000    60.000000
# 50%      65.000000  5.000000e+05   354.000000    65.000000    65.000000
# 75%      70.000000  1.200000e+06   383.000000    70.000000    70.000000
# max      92.000000  1.195000e+08   501.000000    91.000000    91.000000
#
#         GKReflexes  DribblingTotal  PhysicalityTotal  GKPositioning  \
# count  2113.000000     2113.000000       2113.000000    2113.000000
# mean     65.952674       65.952674         63.194983      63.194983
# std       7.929891        7.929891          8.409266       8.409266
# min      45.000000       45.000000         38.000000      38.000000
# 25%      60.000000       60.000000         57.000000      57.000000
# 50%      66.000000       66.000000         63.000000      63.000000
# 75%      71.000000       71.000000         69.000000      69.000000
# max      90.000000       90.000000         92.000000      92.000000
#
#         GKHandling  ShootingTotal    Potential  ReleaseClause    Reactions  \
# count  2113.000000    2113.000000  2113.000000   2.113000e+03  2113.000000
# mean     62.738287      62.738287    69.779934   3.543019e+06    58.028396
# std       7.192506       7.192506     6.253131   1.319192e+07    10.690203
# min      43.000000      43.000000    51.000000   0.000000e+00    25.000000
# 25%      58.000000      58.000000    66.000000   3.940000e+05    51.000000
# 50%      62.000000      62.000000    70.000000   8.550000e+05    59.000000
# 75%      67.000000      67.000000    74.000000   2.100000e+06    66.000000
# max      92.000000      92.000000    93.000000   2.380000e+08    88.000000
#
#        PassingTotal    GKKicking    ShotPower        WageEUR   TotalStats
# count   2113.000000  2113.000000  2113.000000    2113.000000  2113.000000
# mean      61.734501    61.734501    46.434927    6348.887837  1046.335069
# std        7.279396     7.279396     5.473736   15653.275248   142.381724
# min       40.000000    40.000000    30.000000     500.000000   767.000000
# 25%       57.000000    57.000000    43.000000     750.000000   924.000000
# 50%       61.000000    61.000000    46.000000    2000.000000  1048.000000
# 75%       66.000000    66.000000    50.000000    5000.000000  1153.000000
# max       93.000000    93.000000    70.000000  250000.000000  1583.000000

# %% [markdown]
# From the table above we see that our feature are plotted on diffrent scales for exmaple most of the data is on the scale of **0 - 100** while the other features range on scales such as from **0 - 238,000,000** rescaling our data will be important in our training.
#
# We will use the L1 normalization to rescale our data we will do this by modifying values in each of our rows in teh dataset the sum of the sbsolute will always be 1

# %%
# rescaling our features using minmax scaler 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
g_norm = pd.DataFrame(scaler.fit_transform(goal1.values))
g_norm.columns = goal1.columns

#adding index 
i = pd.DataFrame(goal1.index)
g_norm1 = pd.concat([g_norm, i], axis = 1)
g_norm2 = g_norm1.set_index('index')

# %%
#describing our rescaled dataframe 
g_norm2.describe()
# Out:
#           GKRating     ValueEUR    BaseStats    PaceTotal     GKDiving  \
# count  2113.000000  2113.000000  2113.000000  2113.000000  2113.000000
# mean      0.374613     0.016204     0.394609     0.469426     0.469426
# std       0.170920     0.055927     0.173839     0.152778     0.152778
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.255814     0.002017     0.269710     0.367347     0.367347
# 50%       0.372093     0.004109     0.390041     0.469388     0.469388
# 75%       0.488372     0.009967     0.510373     0.571429     0.571429
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#         GKReflexes  DribblingTotal  PhysicalityTotal  GKPositioning  \
# count  2113.000000     2113.000000       2113.000000    2113.000000
# mean      0.465615        0.465615          0.466574       0.466574
# std       0.176220        0.176220          0.155727       0.155727
# min       0.000000        0.000000          0.000000       0.000000
# 25%       0.333333        0.333333          0.351852       0.351852
# 50%       0.466667        0.466667          0.462963       0.462963
# 75%       0.577778        0.577778          0.574074       0.574074
# max       1.000000        1.000000          1.000000       1.000000
#
#         GKHandling  ShootingTotal    Potential  ReleaseClause    Reactions  \
# count  2113.000000    2113.000000  2113.000000    2113.000000  2113.000000
# mean      0.402822       0.402822     0.447141       0.014887     0.524260
# std       0.146786       0.146786     0.148884       0.055428     0.169686
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.306122       0.306122     0.357143       0.001655     0.412698
# 50%       0.387755       0.387755     0.452381       0.003592     0.539683
# 75%       0.489796       0.489796     0.547619       0.008824     0.650794
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        PassingTotal    GKKicking    ShotPower      WageEUR   TotalStats
# count   2113.000000  2113.000000  2113.000000  2113.000000  2113.000000
# mean       0.410085     0.410085     0.410873     0.023442     0.342322
# std        0.137347     0.137347     0.136843     0.062739     0.174487
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%        0.320755     0.320755     0.325000     0.001002     0.192402
# 50%        0.396226     0.396226     0.400000     0.006012     0.344363
# 75%        0.490566     0.490566     0.500000     0.018036     0.473039
# max        1.000000     1.000000     1.000000     1.000000     1.000000

# %%
#checking the distribution of a random variable
sb.displot(g_norm2['GKRating'], bins = 15,kde = True)
plt.title('Distribution', fontsize = 20)
plt.ylabel('Count', fontsize = 18)
plt.xlabel('Bin', fontsize = 18)
plt.show()

# %% [markdown]
# #### Standardization
# Starndardization of our data will be the next step we will do this by changing the datas distribution into bayesian distribution

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(g_norm2.values)
g_norm3 = pd.DataFrame(scaler.transform(g_norm2.values))
g_norm3.columns = goal1.columns

#adding index 
i = pd.DataFrame(goal1.index)
g_normm = pd.concat([g_norm3, i], axis = 1)
g_norm4 = g_normm.set_index('index')
g_norm4.describe()
# Out:
#            GKRating      ValueEUR     BaseStats     PaceTotal      GKDiving  \
# count  2.113000e+03  2.113000e+03  2.113000e+03  2.113000e+03  2.113000e+03
# mean   2.690176e-16 -1.345088e-17  3.228211e-16  1.614106e-16  1.614106e-16
# std    1.000237e+00  1.000237e+00  1.000237e+00  1.000237e+00  1.000237e+00
# min   -2.192263e+00 -2.898078e-01 -2.270501e+00 -3.073342e+00 -3.073342e+00
# 25%   -6.952224e-01 -2.537365e-01 -7.186471e-01 -6.683157e-01 -6.683157e-01
# 50%   -1.474948e-02 -2.163182e-01 -2.628136e-02 -2.529343e-04 -2.529343e-04
# 75%    6.657234e-01 -1.115469e-01  6.660843e-01  6.678099e-01  6.678099e-01
# max    3.659804e+00  1.759480e+01  3.483296e+00  3.473674e+00  3.473674e+00
#
#          GKReflexes  DribblingTotal  PhysicalityTotal  GKPositioning  \
# count  2.113000e+03    2.113000e+03      2.113000e+03   2.113000e+03
# mean  -2.152141e-16   -2.152141e-16     -1.076070e-16  -1.076070e-16
# std    1.000237e+00    1.000237e+00      1.000237e+00   1.000237e+00
# min   -2.642865e+00   -2.642865e+00     -2.996807e+00  -2.996807e+00
# 25%   -7.508404e-01   -7.508404e-01     -7.368598e-01  -7.368598e-01
# 50%    5.969474e-03    5.969474e-03     -2.319223e-02  -2.319223e-02
# 75%    6.366444e-01    6.366444e-01      6.904753e-01   6.904753e-01
# max    3.033209e+00    3.033209e+00      3.426201e+00   3.426201e+00
#
#          GKHandling  ShootingTotal     Potential  ReleaseClause     Reactions  \
# count  2.113000e+03   2.113000e+03  2.113000e+03    2113.000000  2.113000e+03
# mean  -1.614106e-16  -1.614106e-16  5.380352e-17       0.000000  6.994458e-16
# std    1.000237e+00   1.000237e+00  1.000237e+00       1.000237  1.000237e+00
# min   -2.744935e+00  -2.744935e+00 -3.003996e+00      -0.268638 -3.090326e+00
# 25%   -6.589371e-01  -6.589371e-01 -6.046297e-01      -0.238765 -6.576170e-01
# 50%   -1.026710e-01  -1.026710e-01  3.520130e-02      -0.203811  9.090888e-02
# 75%    5.926616e-01   5.926616e-01  6.750323e-01      -0.109412  7.458690e-01
# max    4.069325e+00   4.069325e+00  3.714230e+00      17.776977  2.804315e+00
#
#        PassingTotal     GKKicking     ShotPower       WageEUR    TotalStats
# count  2.113000e+03  2.113000e+03  2.113000e+03  2.113000e+03  2.113000e+03
# mean   3.228211e-16  3.228211e-16  4.304282e-16  2.690176e-17 -2.152141e-16
# std    1.000237e+00  1.000237e+00  1.000237e+00  1.000237e+00  1.000237e+00
# min   -2.986463e+00 -2.986463e+00 -3.003217e+00 -3.737411e-01 -1.962339e+00
# 25%   -6.505514e-01 -6.505514e-01 -6.276772e-01 -3.577662e-01 -8.594082e-01
# 50%   -1.009252e-01 -1.009252e-01 -7.947580e-02 -2.778918e-01  1.169620e-02
# 75%    5.861075e-01  5.861075e-01  6.514594e-01 -8.619328e-02  7.493250e-01
# max    4.296084e+00  4.296084e+00  4.306136e+00  1.556919e+01  3.770090e+00

# %% [markdown]
# ### Group 2

# %% [markdown]
# #### Mutual information

# %%
#choosing the label and predictor
g2_x = g2.drop(columns = ['Overall', 'BestPosition'])
g2_y = g2[['Overall']]
#using mutual information score to asses importance of each column 
discrete_features = g2_x.dtypes == int
mi_scores = make_mi_scores(g2_x, g2_y, discrete_features)
mi_scores.head(60)
# Out:
# RBRating            1.500190
# LBRating            1.500190
# CBRating            1.449482
# ValueEUR            1.413394
# CDMRating           1.353485
# RWBRating           1.167513
# LWBRating           1.167513
# ReleaseClause       1.159346
# DefendingTotal      1.030320
# Potential           0.848086
# Interceptions       0.844122
# Reactions           0.813884
# SlidingTackle       0.807720
# StandingTackle      0.805291
# Marking             0.767986
# WageEUR             0.666581
# CMRating            0.630134
# ShortPassing        0.617553
# Composure           0.610343
# BaseStats           0.573668
# TotalStats          0.530222
# BallControl         0.525810
# LMRating            0.491454
# RMRating            0.491454
# Club                0.462887
# Defence             0.450029
# Team_Overall        0.442620
# CAMRating           0.439351
# STRating            0.435003
# PassingTotal        0.434153
# LongPassing         0.410451
# Midfield            0.398872
# RFRating            0.398169
# CFRating            0.398169
# LFRating            0.398169
# LWRating            0.385586
# RWRating            0.385586
# HeadingAccuracy     0.362860
# DribblingTotal      0.354683
# Attack              0.337368
# League              0.330136
# Aggression          0.324457
# Crossing            0.300027
# TransferBudget      0.287018
# PhysicalityTotal    0.266130
# Dribbling           0.250124
# Vision              0.232767
# ShotPower           0.213329
# GKRating            0.189577
# ShootingTotal       0.189057
# Growth              0.177795
# Stamina             0.166303
# Nationality         0.161319
# Age                 0.155219
# LongShots           0.146496
# Curve               0.145165
# Positioning         0.139482
# Finishing           0.128686
# IntReputation       0.126093
# Volleys             0.117068
# Name: MI Scores, dtype: float64

# %%
#plotting the mi scores
plt.figure(dpi=70, figsize=(10, 30))
plot_mi_scores(mi_scores)

# %%
#selecting features with mi scores more than 0.5
m1_scores = pd.DataFrame(mi_scores).reset_index()
m2_scores = m1_scores.rename(columns = {'index' : 'feature'})
m3_score = m2_scores[m2_scores['MI Scores'] >= 0.5]
#selecting the features
g2_x1 = g2_x[m3_score.feature.unique()]
#checking on the correlation of our variables
g2_x1.corr()
# Out:
#                 RBRating  LBRating  CBRating  ValueEUR  CDMRating  RWBRating  \
# RBRating        1.000000  1.000000  0.839695  0.557226   0.932614   0.986638
# LBRating        1.000000  1.000000  0.839695  0.557226   0.932614   0.986638
# CBRating        0.839695  0.839695  1.000000  0.550729   0.930579   0.763073
# ValueEUR        0.557226  0.557226  0.550729  1.000000   0.535018   0.522341
# CDMRating       0.932614  0.932614  0.930579  0.535018   1.000000   0.900292
# RWBRating       0.986638  0.986638  0.763073  0.522341   0.900292   1.000000
# LWBRating       0.986638  0.986638  0.763073  0.522341   0.900292   1.000000
# ReleaseClause   0.533857  0.533857  0.527555  0.977232   0.512343   0.500045
# DefendingTotal  0.805144  0.805144  0.969407  0.531348   0.894210   0.719894
# Potential       0.632681  0.632681  0.645018  0.553581   0.600709   0.589028
# Interceptions   0.810654  0.810654  0.917578  0.513775   0.884489   0.743086
# Reactions       0.853751  0.853751  0.845948  0.529859   0.878759   0.814461
# SlidingTackle   0.815356  0.815356  0.897175  0.532604   0.841198   0.741840
# StandingTackle  0.787337  0.787337  0.921620  0.531408   0.847563   0.705893
# Marking         0.765898  0.765898  0.914446  0.494990   0.858159   0.690370
# WageEUR         0.604255  0.604255  0.607467  0.805516   0.598391   0.566814
# CMRating        0.903579  0.903579  0.701505  0.453335   0.896359   0.931989
# ShortPassing    0.836973  0.836973  0.755279  0.429365   0.897709   0.837180
# Composure       0.777452  0.777452  0.789792  0.440569   0.842323   0.747093
# BaseStats       0.912029  0.912029  0.663039  0.452007   0.832876   0.942170
# TotalStats      0.894981  0.894981  0.654357  0.431789   0.832005   0.925288
# BallControl     0.850959  0.850959  0.646789  0.409419   0.819007   0.879288
#
#                 LWBRating  ReleaseClause  DefendingTotal  Potential  ...  \
# RBRating         0.986638       0.533857        0.805144   0.632681  ...
# LBRating         0.986638       0.533857        0.805144   0.632681  ...
# CBRating         0.763073       0.527555        0.969407   0.645018  ...
# ValueEUR         0.522341       0.977232        0.531348   0.553581  ...
# CDMRating        0.900292       0.512343        0.894210   0.600709  ...
# RWBRating        1.000000       0.500045        0.719894   0.589028  ...
# LWBRating        1.000000       0.500045        0.719894   0.589028  ...
# ReleaseClause    0.500045       1.000000        0.510286   0.532573  ...
# DefendingTotal   0.719894       0.510286        1.000000   0.613949  ...
# Potential        0.589028       0.532573        0.613949   1.000000  ...
# Interceptions    0.743086       0.492851        0.938414   0.584916  ...
# Reactions        0.814461       0.507225        0.829012   0.567298  ...
# SlidingTackle    0.741840       0.512293        0.917257   0.627131  ...
# StandingTackle   0.705893       0.510683        0.952984   0.640554  ...
# Marking          0.690370       0.475556        0.953210   0.546897  ...
# WageEUR          0.566814       0.780849        0.599412   0.525353  ...
# CMRating         0.931989       0.433444        0.642959   0.488363  ...
# ShortPassing     0.837180       0.411979        0.701824   0.514054  ...
# Composure        0.747093       0.417260        0.771199   0.463663  ...
# BaseStats        0.942170       0.430355        0.584834   0.487832  ...
# TotalStats       0.925288       0.411305        0.591070   0.447550  ...
# BallControl      0.879288       0.389869        0.586230   0.504334  ...
#
#                 SlidingTackle  StandingTackle   Marking   WageEUR  CMRating  \
# RBRating             0.815356        0.787337  0.765898  0.604255  0.903579
# LBRating             0.815356        0.787337  0.765898  0.604255  0.903579
# CBRating             0.897175        0.921620  0.914446  0.607467  0.701505
# ValueEUR             0.532604        0.531408  0.494990  0.805516  0.453335
# CDMRating            0.841198        0.847563  0.858159  0.598391  0.896359
# RWBRating            0.741840        0.705893  0.690370  0.566814  0.931989
# LWBRating            0.741840        0.705893  0.690370  0.566814  0.931989
# ReleaseClause        0.512293        0.510683  0.475556  0.780849  0.433444
# DefendingTotal       0.917257        0.952984  0.953210  0.599412  0.642959
# Potential            0.627131        0.640554  0.546897  0.525353  0.488363
# Interceptions        0.844005        0.862771  0.877998  0.581984  0.673734
# Reactions            0.782238        0.778246  0.798351  0.588246  0.767853
# SlidingTackle        1.000000        0.922367  0.829224  0.595663  0.637185
# StandingTackle       0.922367        1.000000  0.858947  0.590138  0.612425
# Marking              0.829224        0.858947  1.000000  0.560429  0.623866
# WageEUR              0.595663        0.590138  0.560429  1.000000  0.510217
# CMRating             0.637185        0.612425  0.623866  0.510217  1.000000
# ShortPassing         0.661456        0.666947  0.676608  0.479075  0.888204
# Composure            0.713868        0.714777  0.751770  0.507510  0.761016
# BaseStats            0.603230        0.564157  0.567882  0.494440  0.950044
# TotalStats           0.608813        0.562963  0.575696  0.488983  0.954948
# BallControl          0.587537        0.566765  0.568334  0.455813  0.903689
#
#                 ShortPassing  Composure  BaseStats  TotalStats  BallControl
# RBRating            0.836973   0.777452   0.912029    0.894981     0.850959
# LBRating            0.836973   0.777452   0.912029    0.894981     0.850959
# CBRating            0.755279   0.789792   0.663039    0.654357     0.646789
# ValueEUR            0.429365   0.440569   0.452007    0.431789     0.409419
# CDMRating           0.897709   0.842323   0.832876    0.832005     0.819007
# RWBRating           0.837180   0.747093   0.942170    0.925288     0.879288
# LWBRating           0.837180   0.747093   0.942170    0.925288     0.879288
# ReleaseClause       0.411979   0.417260   0.430355    0.411305     0.389869
# DefendingTotal      0.701824   0.771199   0.584834    0.591070     0.586230
# Potential           0.514054   0.463663   0.487832    0.447550     0.504334
# Interceptions       0.697434   0.761824   0.614422    0.623865     0.611301
# Reactions           0.733124   0.778249   0.717512    0.730404     0.695960
# SlidingTackle       0.661456   0.713868   0.603230    0.608813     0.587537
# StandingTackle      0.666947   0.714777   0.564157    0.562963     0.566765
# Marking             0.676608   0.751770   0.567882    0.575696     0.568334
# WageEUR             0.479075   0.507510   0.494440    0.488983     0.455813
# CMRating            0.888204   0.761016   0.950044    0.954948     0.903689
# ShortPassing        1.000000   0.731698   0.797044    0.792885     0.819948
# Composure           0.731698   1.000000   0.709048    0.723190     0.684304
# BaseStats           0.797044   0.709048   1.000000    0.981275     0.859897
# TotalStats          0.792885   0.723190   0.981275    1.000000     0.847497
# BallControl         0.819948   0.684304   0.859897    0.847497     1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# #### Multicollinearity

# %%
#selecting the features
def1 = g2_x1.copy()

# %%
# set figure size
plt.figure(figsize=(10,7))

# Generate a mask to onlyshow the bottom triangle
mask = np.triu(np.ones_like(def1.corr(), dtype=bool))
# generate heatmap
sb.heatmap(def1.corr(), mask=mask, vmin=-1, vmax=1 ,cmap="YlGnBu", center = 0)
plt.title('Correlation Coefficient Of Predictors')
plt.show()

# %%
#plotting a cluster map
sb.clustermap(def1.corr(), figsize=(20,20), cmap = "YlGnBu")

# %%
#checking the vif scores for our data
y = compute_vif(def1)
def1.drop(columns = ['intercept'], inplace = True)
y
# Out:
#           Variable         VIF
# 0         RBRating         inf
# 1         LBRating         inf
# 2         CBRating   55.170551
# 3         ValueEUR   25.374171
# 4        CDMRating  106.751475
# 5        RWBRating         inf
# 6        LWBRating         inf
# 7    ReleaseClause   22.421697
# 8   DefendingTotal  186.060041
# 9        Potential    2.340547
# 10   Interceptions   16.581896
# 11       Reactions    5.878131
# 12   SlidingTackle   10.518751
# 13  StandingTackle   24.729537
# 14         Marking   25.894453
# 15         WageEUR    3.313440
# 16        CMRating   64.296291
# 17    ShortPassing    8.786922
# 18       Composure    3.784267
# 19       BaseStats   60.859529
# 20      TotalStats   41.418366
# 21     BallControl    6.557701

# %%
#describing our features
def1.describe()
# Out:
#           RBRating     LBRating     CBRating      ValueEUR    CDMRating  \
# count  6464.000000  6464.000000  6464.000000  6.464000e+03  6464.000000
# mean     64.347308    64.347308    65.750928  2.525258e+06    63.599629
# std       6.525771     6.525771     6.561401  6.210113e+06     7.189935
# min      46.000000    46.000000    45.000000  0.000000e+00    42.000000
# 25%      60.000000    60.000000    62.000000  4.750000e+05    59.000000
# 50%      64.000000    64.000000    66.000000  9.250000e+05    64.000000
# 75%      68.000000    68.000000    70.000000  1.900000e+06    68.000000
# max      87.000000    87.000000    89.000000  1.140000e+08    88.000000
#
#          RWBRating    LWBRating  ReleaseClause  DefendingTotal    Potential  \
# count  6464.000000  6464.000000   6.464000e+03     6464.000000  6464.000000
# mean     63.450186    63.450186   4.506180e+06       63.997834    70.803837
# std       6.974501     6.974501   1.189996e+07        7.198754     5.905351
# min      44.000000    44.000000   0.000000e+00       43.000000    50.000000
# 25%      59.000000    59.000000   7.120000e+05       59.000000    67.000000
# 50%      63.000000    63.000000   1.500000e+06       64.000000    70.000000
# 75%      68.000000    68.000000   3.300000e+06       69.000000    75.000000
# max      88.000000    88.000000   2.195000e+08       91.000000    92.000000
#
#        ...  SlidingTackle  StandingTackle      Marking        WageEUR  \
# count  ...    6464.000000     6464.000000  6464.000000    6464.000000
# mean   ...      64.178682       65.939975    63.370514    8507.990408
# std    ...       7.050081        7.009892     7.958538   16833.342427
# min    ...      42.000000       42.000000    34.000000     500.000000
# 25%    ...      60.000000       62.000000    58.000000    1000.000000
# 50%    ...      64.000000       66.000000    63.000000    3000.000000
# 75%    ...      69.000000       70.000000    69.000000    8000.000000
# max    ...      92.000000       92.000000    93.000000  230000.000000
#
#           CMRating  ShortPassing    Composure    BaseStats   TotalStats  \
# count  6464.000000   6464.000000  6464.000000  6464.000000  6464.000000
# mean     57.635829     59.955136    57.599010   347.334158  1609.824567
# std       8.544255      9.543705    10.155153    41.409176   197.193605
# min      34.000000     23.000000    30.000000   227.000000  1068.000000
# 25%      52.000000     55.000000    50.000000   318.000000  1464.000000
# 50%      58.000000     61.000000    58.000000   346.000000  1599.000000
# 75%      63.000000     66.000000    65.000000   376.000000  1745.000000
# max      87.000000     88.000000    90.000000   482.000000  2292.000000
#
#        BallControl
# count  6464.000000
# mean     58.333075
# std       9.916141
# min      24.000000
# 25%      53.000000
# 50%      59.000000
# 75%      65.000000
# max      88.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# #### Rescaling

# %%
# rescaling our features using minmax scaler 
d_norm = pd.DataFrame(scaler.fit_transform(def1.values))
d_norm.columns = def1.columns

#adding index 
i = pd.DataFrame(def1.index)
d_norm1 = pd.concat([d_norm, i], axis = 1)
d_norm2 = d_norm1.set_index('index')

#describing our rescaled dataframe 
d_norm2.describe()
# Out:
#            RBRating      LBRating      CBRating      ValueEUR     CDMRating  \
# count  6.464000e+03  6.464000e+03  6.464000e+03  6.464000e+03  6.464000e+03
# mean   4.572800e-16  4.572800e-16  3.165784e-16  1.758769e-17  1.055261e-16
# std    1.000077e+00  1.000077e+00  1.000077e+00  1.000077e+00  1.000077e+00
# min   -2.811733e+00 -2.811733e+00 -3.162820e+00 -4.066678e-01 -3.004380e+00
# 25%   -6.662269e-01 -6.662269e-01 -5.717099e-01 -3.301737e-01 -6.397811e-01
# 50%   -5.322513e-02 -5.322513e-02  3.796309e-02 -2.577057e-01  5.568928e-02
# 75%    5.597767e-01  5.597767e-01  6.476361e-01 -1.006916e-01  6.120656e-01
# max    3.471535e+00  3.471535e+00  3.543583e+00  1.795191e+01  3.393947e+00
#
#           RWBRating     LWBRating  ReleaseClause  DefendingTotal  \
# count  6.464000e+03  6.464000e+03    6464.000000    6.464000e+03
# mean   4.924554e-16  4.924554e-16       0.000000    3.517538e-17
# std    1.000077e+00  1.000077e+00       1.000077    1.000077e+00
# min   -2.788973e+00 -2.788973e+00      -0.378701   -2.917096e+00
# 25%   -6.381145e-01 -6.381145e-01      -0.318864   -6.943175e-01
# 50%   -6.455236e-02 -6.455236e-02      -0.252641    3.008867e-04
# 75%    6.524003e-01  6.524003e-01      -0.101368    6.949193e-01
# max    3.520211e+00  3.520211e+00      18.068173    3.751240e+00
#
#           Potential  ...  SlidingTackle  StandingTackle       Marking  \
# count  6.464000e+03  ...   6.464000e+03    6.464000e+03  6.464000e+03
# mean   8.793846e-17  ...  -6.683323e-16   -6.331569e-16  2.989908e-16
# std    1.000077e+00  ...   1.000077e+00    1.000077e+00  1.000077e+00
# min   -3.523152e+00  ...  -3.146120e+00   -3.415434e+00 -3.690726e+00
# 25%   -6.441838e-01  ...  -5.927599e-01   -5.621028e-01 -6.748638e-01
# 50%   -1.361306e-01  ...  -2.534662e-02    8.563526e-03 -4.655909e-02
# 75%    7.106247e-01  ...   6.839200e-01    5.792298e-01  7.074065e-01
# max    3.589593e+00  ...   3.946546e+00    3.717895e+00  3.723269e+00
#
#             WageEUR      CMRating  ShortPassing     Composure     BaseStats  \
# count  6.464000e+03  6.464000e+03  6.464000e+03  6.464000e+03  6.464000e+03
# mean  -3.517538e-17 -1.407015e-16  1.758769e-16  1.758769e-16  6.331569e-16
# std    1.000077e+00  1.000077e+00  1.000077e+00  1.000077e+00  1.000077e+00
# min   -4.757587e-01 -2.766497e+00 -3.872500e+00 -2.717945e+00 -2.906203e+00
# 25%   -4.460535e-01 -6.596556e-01 -5.192448e-01 -7.483489e-01 -7.084523e-01
# 50%   -3.272325e-01  4.262501e-02  1.094905e-01  3.948942e-02 -3.222140e-02
# 75%   -3.017997e-02  6.278588e-01  6.334365e-01  7.288480e-01  6.923118e-01
# max    1.315895e+01  3.436981e+00  2.938799e+00  3.190843e+00  3.252329e+00
#
#          TotalStats   BallControl
# count  6.464000e+03  6.464000e+03
# mean   2.814031e-16 -1.407015e-16
# std    1.000077e+00  1.000077e+00
# min   -2.747891e+00 -3.462610e+00
# 25%   -7.395567e-01 -5.378592e-01
# 50%   -5.489734e-02  6.726166e-02
# 75%    6.855491e-01  6.723825e-01
# max    3.459687e+00  2.992013e+00
#
# [8 rows x 22 columns]

# %%
#checking the distribution of a random variable
sb.displot(d_norm2['TotalStats'], bins = 15,kde = True)
plt.title('Distribution', fontsize = 20)
plt.ylabel('Count', fontsize = 18)
plt.xlabel('Bin', fontsize = 18)
plt.show()

# %% [markdown]
# #### Standardization

# %%
#standardizing our data
scaler = StandardScaler().fit(d_norm2.values)
d_norm3 = pd.DataFrame(scaler.transform(d_norm2.values))
d_norm3.columns = def1.columns

#adding index 
i = pd.DataFrame(def1.index)
d_normm = pd.concat([d_norm3, i], axis = 1)
d_norm4 = d_normm.set_index('index')
d_norm4.describe()
# Out:
#           RBRating     LBRating      CBRating      ValueEUR     CDMRating  \
# count  6464.000000  6464.000000  6.464000e+03  6.464000e+03  6.464000e+03
# mean      0.000000     0.000000 -3.517538e-17 -1.758769e-17  3.517538e-17
# std       1.000077     1.000077  1.000077e+00  1.000077e+00  1.000077e+00
# min      -2.811733    -2.811733 -3.162820e+00 -4.066678e-01 -3.004380e+00
# 25%      -0.666227    -0.666227 -5.717099e-01 -3.301737e-01 -6.397811e-01
# 50%      -0.053225    -0.053225  3.796309e-02 -2.577057e-01  5.568928e-02
# 75%       0.559777     0.559777  6.476361e-01 -1.006916e-01  6.120656e-01
# max       3.471535     3.471535  3.543583e+00  1.795191e+01  3.393947e+00
#
#          RWBRating    LWBRating  ReleaseClause  DefendingTotal    Potential  \
# count  6464.000000  6464.000000    6464.000000    6.464000e+03  6464.000000
# mean      0.000000     0.000000       0.000000    3.517538e-17     0.000000
# std       1.000077     1.000077       1.000077    1.000077e+00     1.000077
# min      -2.788973    -2.788973      -0.378701   -2.917096e+00    -3.523152
# 25%      -0.638114    -0.638114      -0.318864   -6.943175e-01    -0.644184
# 50%      -0.064552    -0.064552      -0.252641    3.008867e-04    -0.136131
# 75%       0.652400     0.652400      -0.101368    6.949193e-01     0.710625
# max       3.520211     3.520211      18.068173    3.751240e+00     3.589593
#
#        ...  SlidingTackle  StandingTackle      Marking      WageEUR  \
# count  ...    6464.000000    6.464000e+03  6464.000000  6464.000000
# mean   ...       0.000000    3.517538e-17     0.000000     0.000000
# std    ...       1.000077    1.000077e+00     1.000077     1.000077
# min    ...      -3.146120   -3.415434e+00    -3.690726    -0.475759
# 25%    ...      -0.592760   -5.621028e-01    -0.674864    -0.446053
# 50%    ...      -0.025347    8.563526e-03    -0.046559    -0.327232
# 75%    ...       0.683920    5.792298e-01     0.707407    -0.030180
# max    ...       3.946546    3.717895e+00     3.723269    13.158952
#
#           CMRating  ShortPassing     Composure     BaseStats   TotalStats  \
# count  6464.000000   6464.000000  6.464000e+03  6.464000e+03  6464.000000
# mean      0.000000      0.000000 -3.517538e-17  7.035077e-17     0.000000
# std       1.000077      1.000077  1.000077e+00  1.000077e+00     1.000077
# min      -2.766497     -3.872500 -2.717945e+00 -2.906203e+00    -2.747891
# 25%      -0.659656     -0.519245 -7.483489e-01 -7.084523e-01    -0.739557
# 50%       0.042625      0.109490  3.948942e-02 -3.222140e-02    -0.054897
# 75%       0.627859      0.633437  7.288480e-01  6.923118e-01     0.685549
# max       3.436981      2.938799  3.190843e+00  3.252329e+00     3.459687
#
#        BallControl
# count  6464.000000
# mean      0.000000
# std       1.000077
# min      -3.462610
# 25%      -0.537859
# 50%       0.067262
# 75%       0.672383
# max       2.992013
#
# [8 rows x 22 columns]

# %%
#checking the distribution of a random variable
sb.displot(d_norm2['TotalStats'], bins = 15,kde = True)
plt.title('Distribution', fontsize = 20)
plt.ylabel('Count', fontsize = 18)
plt.xlabel('Bin', fontsize = 18)
plt.show()

# %% [markdown]
# ### Group 3

# %% [markdown]
# #### Mutual information

# %%
#choosing the label and predictor
g3_x = g3.drop(columns = ['Overall', 'BestPosition'])
g3_y = g3[['Overall']]
#using mutual information score to asses importance of each column 
discrete_features = g3_x.dtypes == int
mi_scores = make_mi_scores(g3_x, g3_y, discrete_features)
mi_scores.head(60)
# Out:
# ValueEUR            1.531584
# RMRating            1.337695
# LMRating            1.337695
# CAMRating           1.323608
# CMRating            1.183948
# RFRating            1.167041
# LFRating            1.167041
# CFRating            1.167041
# LWRating            1.162285
# RWRating            1.162285
# ReleaseClause       1.139569
# STRating            0.924259
# BallControl         0.893479
# BaseStats           0.857502
# PassingTotal        0.820916
# TotalStats          0.818136
# Potential           0.787226
# Reactions           0.772225
# DribblingTotal      0.727088
# CDMRating           0.699674
# ShortPassing        0.687116
# WageEUR             0.670296
# LWBRating           0.653672
# RWBRating           0.653672
# Vision              0.625376
# Dribbling           0.612552
# RBRating            0.589388
# LBRating            0.589388
# Composure           0.578324
# Positioning         0.535376
# ShootingTotal       0.521661
# LongPassing         0.448580
# CBRating            0.445488
# LongShots           0.442628
# Crossing            0.419070
# Club                0.403120
# ShotPower           0.384734
# Team_Overall        0.380802
# Midfield            0.375764
# Finishing           0.369159
# Curve               0.344104
# DefendingTotal      0.338573
# Defence             0.330925
# League              0.299571
# Attack              0.296028
# Interceptions       0.289801
# TransferBudget      0.286687
# Volleys             0.269842
# StandingTackle      0.268380
# Marking             0.235718
# FKAccuracy          0.232224
# SlidingTackle       0.203908
# Stamina             0.203246
# Growth              0.195612
# GKRating            0.190253
# Penalties           0.183486
# SkillMoves          0.175469
# Age                 0.175245
# HeadingAccuracy     0.174706
# PhysicalityTotal    0.170474
# Name: MI Scores, dtype: float64

# %%
#plotting the mi scores
plt.figure(dpi=70, figsize=(10, 30))
plot_mi_scores(mi_scores)

# %%
#selecting features with mi scores more than 0.5
m1_scores = pd.DataFrame(mi_scores).reset_index()
m2_scores = m1_scores.rename(columns = {'index' : 'feature'})
m3_score = m2_scores[m2_scores['MI Scores'] >= 0.5]
#selecting the features
g3_x1 = g3_x[m3_score.feature.unique()]
#checking on the correlation of our variables
g3_x1.corr()
# Out:
#                 ValueEUR  RMRating  LMRating  CAMRating  CMRating  RFRating  \
# ValueEUR        1.000000  0.582923  0.582923   0.584682  0.546413  0.552227
# RMRating        0.582923  1.000000  1.000000   0.985335  0.871028  0.979711
# LMRating        0.582923  1.000000  1.000000   0.985335  0.871028  0.979711
# CAMRating       0.584682  0.985335  0.985335   1.000000  0.903371  0.982899
# CMRating        0.546413  0.871028  0.871028   0.903371  1.000000  0.851468
# RFRating        0.552227  0.979711  0.979711   0.982899  0.851468  1.000000
# LFRating        0.552227  0.979711  0.979711   0.982899  0.851468  1.000000
# CFRating        0.552227  0.979711  0.979711   0.982899  0.851468  1.000000
# LWRating        0.543884  0.982121  0.982121   0.969289  0.802987  0.986835
# RWRating        0.543884  0.982121  0.982121   0.969289  0.802987  0.986835
# ReleaseClause   0.970547  0.550174  0.550174   0.552514  0.518416  0.520348
# STRating        0.533694  0.945068  0.945068   0.946419  0.830614  0.976560
# BallControl     0.546855  0.910206  0.910206   0.927368  0.869445  0.904674
# BaseStats       0.507394  0.878343  0.878343   0.876685  0.921911  0.861814
# PassingTotal    0.516151  0.884807  0.884807   0.906013  0.931890  0.867440
# TotalStats      0.496474  0.864002  0.864002   0.875593  0.940648  0.855699
# Potential       0.543710  0.650457  0.650457   0.652919  0.574731  0.602865
# Reactions       0.516737  0.798072  0.798072   0.819684  0.882926  0.792395
# DribblingTotal  0.531853  0.937925  0.937925   0.932119  0.769065  0.932021
# CDMRating       0.358985  0.508149  0.508149   0.546101  0.833643  0.467056
# ShortPassing    0.505173  0.781882  0.781882   0.825578  0.932560  0.758515
# WageEUR         0.832993  0.586548  0.586548   0.592438  0.572547  0.563402
# LWBRating       0.413479  0.634948  0.634948   0.646401  0.871190  0.581490
# RWBRating       0.413479  0.634948  0.634948   0.646401  0.871190  0.581490
# Vision          0.491566  0.832988  0.832988   0.876502  0.875162  0.838153
# Dribbling       0.502771  0.902785  0.902785   0.892367  0.707493  0.903274
# RBRating        0.360501  0.533195  0.533195   0.549343  0.810506  0.481112
# LBRating        0.360501  0.533195  0.533195   0.549343  0.810506  0.481112
# Composure       0.473056  0.777425  0.777425   0.802578  0.815755  0.777166
# Positioning     0.443563  0.834528  0.834528   0.835358  0.692211  0.876256
# ShootingTotal   0.435209  0.842384  0.842384   0.853920  0.688247  0.907072
#
#                 LFRating  CFRating  LWRating  RWRating  ...   WageEUR  \
# ValueEUR        0.552227  0.552227  0.543884  0.543884  ...  0.832993
# RMRating        0.979711  0.979711  0.982121  0.982121  ...  0.586548
# LMRating        0.979711  0.979711  0.982121  0.982121  ...  0.586548
# CAMRating       0.982899  0.982899  0.969289  0.969289  ...  0.592438
# CMRating        0.851468  0.851468  0.802987  0.802987  ...  0.572547
# RFRating        1.000000  1.000000  0.986835  0.986835  ...  0.563402
# LFRating        1.000000  1.000000  0.986835  0.986835  ...  0.563402
# CFRating        1.000000  1.000000  0.986835  0.986835  ...  0.563402
# LWRating        0.986835  0.986835  1.000000  1.000000  ...  0.548968
# RWRating        0.986835  0.986835  1.000000  1.000000  ...  0.548968
# ReleaseClause   0.520348  0.520348  0.512009  0.512009  ...  0.790227
# STRating        0.976560  0.976560  0.951949  0.951949  ...  0.551130
# BallControl     0.904674  0.904674  0.887815  0.887815  ...  0.572115
# BaseStats       0.861814  0.861814  0.831365  0.831365  ...  0.528472
# PassingTotal    0.867440  0.867440  0.844727  0.844727  ...  0.552905
# TotalStats      0.855699  0.855699  0.818409  0.818409  ...  0.531059
# Potential       0.602865  0.602865  0.601599  0.601599  ...  0.492165
# Reactions       0.792395  0.792395  0.744858  0.744858  ...  0.540033
# DribblingTotal  0.932021  0.932021  0.949437  0.949437  ...  0.536718
# CDMRating       0.467056  0.467056  0.395810  0.395810  ...  0.397595
# ShortPassing    0.758515  0.758515  0.709103  0.709103  ...  0.538740
# WageEUR         0.563402  0.563402  0.548968  0.548968  ...  1.000000
# LWBRating       0.581490  0.581490  0.533642  0.533642  ...  0.445503
# RWBRating       0.581490  0.581490  0.533642  0.533642  ...  0.445503
# Vision          0.838153  0.838153  0.803217  0.803217  ...  0.509930
# Dribbling       0.903274  0.903274  0.920862  0.920862  ...  0.504902
# RBRating        0.481112  0.481112  0.425714  0.425714  ...  0.394215
# LBRating        0.481112  0.481112  0.425714  0.425714  ...  0.394215
# Composure       0.777166  0.777166  0.744627  0.744627  ...  0.505088
# Positioning     0.876256  0.876256  0.857452  0.857452  ...  0.454735
# ShootingTotal   0.907072  0.907072  0.888360  0.888360  ...  0.457247
#
#                 LWBRating  RWBRating    Vision  Dribbling  RBRating  LBRating  \
# ValueEUR         0.413479   0.413479  0.491566   0.502771  0.360501  0.360501
# RMRating         0.634948   0.634948  0.832988   0.902785  0.533195  0.533195
# LMRating         0.634948   0.634948  0.832988   0.902785  0.533195  0.533195
# CAMRating        0.646401   0.646401  0.876502   0.892367  0.549343  0.549343
# CMRating         0.871190   0.871190  0.875162   0.707493  0.810506  0.810506
# RFRating         0.581490   0.581490  0.838153   0.903274  0.481112  0.481112
# LFRating         0.581490   0.581490  0.838153   0.903274  0.481112  0.481112
# CFRating         0.581490   0.581490  0.838153   0.903274  0.481112  0.481112
# LWRating         0.533642   0.533642  0.803217   0.920862  0.425714  0.425714
# RWRating         0.533642   0.533642  0.803217   0.920862  0.425714  0.425714
# ReleaseClause    0.393628   0.393628  0.466474   0.472006  0.343924  0.343924
# STRating         0.587966   0.587966  0.787323   0.845170  0.498999  0.498999
# BallControl      0.629485   0.629485  0.807906   0.860722  0.538864  0.538864
# BaseStats        0.871462   0.871462  0.771579   0.711555  0.816001  0.816001
# PassingTotal     0.731780   0.731780  0.908398   0.741493  0.650149  0.650149
# TotalStats       0.872849   0.872849  0.810547   0.692044  0.817631  0.817631
# Potential        0.405944   0.405944  0.507246   0.622498  0.344979  0.344979
# Reactions        0.766574   0.766574  0.767317   0.629717  0.709016  0.709016
# DribblingTotal   0.500057   0.500057  0.753316   0.972974  0.392982  0.392982
# CDMRating        0.968967   0.968967  0.597997   0.302909  0.977872  0.977872
# ShortPassing     0.781843   0.781843  0.809759   0.629916  0.724966  0.724966
# WageEUR          0.445503   0.445503  0.509930   0.504902  0.394215  0.394215
# LWBRating        1.000000   1.000000  0.637021   0.427256  0.989118  0.989118
# RWBRating        1.000000   1.000000  0.637021   0.427256  0.989118  0.989118
# Vision           0.637021   0.637021  1.000000   0.707308  0.559207  0.559207
# Dribbling        0.427256   0.427256  0.707308   1.000000  0.320501  0.320501
# RBRating         0.989118   0.989118  0.559207   0.320501  1.000000  1.000000
# LBRating         0.989118   0.989118  0.559207   0.320501  1.000000  1.000000
# Composure        0.654547   0.654547  0.777633   0.674310  0.588328  0.588328
# Positioning      0.428808   0.428808  0.714011   0.737424  0.339440  0.339440
# ShootingTotal    0.400973   0.400973  0.712904   0.772204  0.306671  0.306671
#
#                 Composure  Positioning  ShootingTotal
# ValueEUR         0.473056     0.443563       0.435209
# RMRating         0.777425     0.834528       0.842384
# LMRating         0.777425     0.834528       0.842384
# CAMRating        0.802578     0.835358       0.853920
# CMRating         0.815755     0.692211       0.688247
# RFRating         0.777166     0.876256       0.907072
# LFRating         0.777166     0.876256       0.907072
# CFRating         0.777166     0.876256       0.907072
# LWRating         0.744627     0.857452       0.888360
# RWRating         0.744627     0.857452       0.888360
# ReleaseClause    0.447826     0.417377       0.408280
# STRating         0.762451     0.868467       0.932715
# BallControl      0.781485     0.706379       0.745193
# BaseStats        0.773836     0.694512       0.736001
# PassingTotal     0.812292     0.714759       0.748797
# TotalStats       0.807607     0.703738       0.750574
# Potential        0.492344     0.422805       0.435012
# Reactions        0.756831     0.653287       0.627211
# DribblingTotal   0.726615     0.751264       0.781878
# CDMRating        0.606523     0.328196       0.299158
# ShortPassing     0.751678     0.583456       0.583843
# WageEUR          0.505088     0.454735       0.457247
# LWBRating        0.654547     0.428808       0.400973
# RWBRating        0.654547     0.428808       0.400973
# Vision           0.777633     0.714011       0.712904
# Dribbling        0.674310     0.737424       0.772204
# RBRating         0.588328     0.339440       0.306671
# LBRating         0.588328     0.339440       0.306671
# Composure        1.000000     0.645406       0.667210
# Positioning      0.645406     1.000000       0.817276
# ShootingTotal    0.667210     0.817276       1.000000
#
# [31 rows x 31 columns]

# %% [markdown]
# #### Multicollinearity

# %%
#selecting the features
cm1 = g3_x1.copy()

# set figure size
plt.figure(figsize=(10,7))

# Generate a mask to onlyshow the bottom triangle
mask = np.triu(np.ones_like(cm1.corr(), dtype=bool))
# generate heatmap
sb.heatmap(cm1.corr(), mask=mask, vmin=-1, vmax=1 ,cmap="YlGnBu", center = 0)
plt.title('Correlation Coefficient Of Predictors')
plt.show()

# %%
#plotting a cluster map
sb.clustermap(cm1.corr(), figsize=(20,20), cmap = "YlGnBu")

# %%
#checking the vif scores for our data
y = compute_vif(cm1)
cm1.drop(columns = ['intercept'], inplace = True)
y
# Out:
#           Variable         VIF
# 0         ValueEUR   22.253018
# 1         RMRating         inf
# 2         LMRating         inf
# 3        CAMRating  153.713515
# 4         CMRating  110.620663
# 5         RFRating         inf
# 6         LFRating         inf
# 7         CFRating         inf
# 8         LWRating         inf
# 9         RWRating         inf
# 10   ReleaseClause   17.664354
# 11        STRating   88.282394
# 12     BallControl   21.679385
# 13       BaseStats  107.259166
# 14    PassingTotal   49.098778
# 15      TotalStats   87.695537
# 16       Potential    2.702446
# 17       Reactions    9.060334
# 18  DribblingTotal  105.342186
# 19       CDMRating  152.258991
# 20    ShortPassing   23.596943
# 21         WageEUR    3.641473
# 22       LWBRating         inf
# 23       RWBRating         inf
# 24          Vision   13.417178
# 25       Dribbling   38.375418
# 26        RBRating         inf
# 27        LBRating         inf
# 28       Composure    3.761588
# 29     Positioning   12.088584
# 30   ShootingTotal   30.023421

# %%
#describing our features
cm1.describe()
# Out:
#            ValueEUR     RMRating     LMRating    CAMRating     CMRating  \
# count  7.344000e+03  7344.000000  7344.000000  7344.000000  7344.000000
# mean   3.280260e+06    66.050517    66.050517    65.922113    64.578704
# std    8.074404e+06     6.587393     6.587393     6.787583     7.317273
# min    0.000000e+00    46.000000    46.000000    46.000000    41.000000
# 25%    5.500000e+05    62.000000    62.000000    62.000000    60.000000
# 50%    1.100000e+06    66.000000    66.000000    66.000000    65.000000
# 75%    2.400000e+06    70.000000    70.000000    70.000000    69.000000
# max    1.255000e+08    91.000000    91.000000    91.000000    91.000000
#
#           RFRating     LFRating     CFRating     LWRating     RWRating  ...  \
# count  7344.000000  7344.000000  7344.000000  7344.000000  7344.000000  ...
# mean     63.322712    63.322712    63.322712    63.838508    63.838508  ...
# std       7.025015     7.025015     7.025015     6.964810     6.964810  ...
# min      42.000000    42.000000    42.000000    42.000000    42.000000  ...
# 25%      59.000000    59.000000    59.000000    59.000000    59.000000  ...
# 50%      63.000000    63.000000    63.000000    64.000000    64.000000  ...
# 75%      68.000000    68.000000    68.000000    68.000000    68.000000  ...
# max      87.000000    87.000000    87.000000    88.000000    88.000000  ...
#
#              WageEUR    LWBRating    RWBRating       Vision    Dribbling  \
# count    7344.000000  7344.000000  7344.000000  7344.000000  7344.000000
# mean     9486.063453    61.188181    61.188181    63.240468    66.091912
# std     19870.410448     7.957397     7.957397     8.703315     8.243527
# min       500.000000    37.000000    37.000000    31.000000    25.000000
# 25%      1000.000000    56.000000    56.000000    57.000000    61.000000
# 50%      3000.000000    61.000000    61.000000    63.000000    66.000000
# 75%      9000.000000    67.000000    67.000000    69.000000    72.000000
# max    350000.000000    88.000000    88.000000    94.000000    92.000000
#
#           RBRating     LBRating    Composure  Positioning  ShootingTotal
# count  7344.000000  7344.000000  7344.000000  7344.000000    7344.000000
# mean     59.675381    59.675381    61.838780    60.104711      57.526688
# std       8.498032     8.498032     9.952024     9.380530       9.483134
# min      35.000000    35.000000    34.000000    23.000000      26.000000
# 25%      54.000000    54.000000    55.000000    55.000000      51.000000
# 50%      60.000000    60.000000    62.000000    60.000000      58.000000
# 75%      66.000000    66.000000    69.000000    66.000000      64.000000
# max      88.000000    88.000000    94.000000    96.000000      87.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# #### Rescaling

# %%
# rescaling our features using minmax scaler 
c_norm = pd.DataFrame(scaler.fit_transform(cm1.values))
c_norm.columns = cm1.columns

#adding index 
i = pd.DataFrame(cm1.index)
c_norm1 = pd.concat([c_norm, i], axis = 1)
c_norm2 = c_norm1.set_index('index')

#describing our rescaled dataframe 
c_norm2.describe()
# Out:
#           ValueEUR      RMRating      LMRating     CAMRating      CMRating  \
# count  7344.000000  7.344000e+03  7.344000e+03  7.344000e+03  7.344000e+03
# mean      0.000000 -4.334465e-16 -4.334465e-16  2.476837e-16 -7.972320e-16
# std       1.000068  1.000068e+00  1.000068e+00  1.000068e+00  1.000068e+00
# min      -0.406282 -3.043979e+00 -3.043979e+00 -2.935282e+00 -3.222554e+00
# 25%      -0.338161 -6.149312e-01 -6.149312e-01 -5.778758e-01 -6.257817e-01
# 50%      -0.270040 -7.669327e-03 -7.669327e-03  1.147566e-02  5.757950e-02
# 75%      -0.109026  5.995925e-01  5.995925e-01  6.008272e-01  6.042684e-01
# max      15.137720  3.787717e+00  3.787717e+00  3.694923e+00  3.611058e+00
#
#            RFRating      LFRating      CFRating      LWRating      RWRating  \
# count  7.344000e+03  7.344000e+03  7.344000e+03  7.344000e+03  7.344000e+03
# mean  -3.096047e-17 -3.096047e-17 -3.096047e-17  4.334465e-16  4.334465e-16
# std    1.000068e+00  1.000068e+00  1.000068e+00  1.000068e+00  1.000068e+00
# min   -3.035462e+00 -3.035462e+00 -3.035462e+00 -3.135763e+00 -3.135763e+00
# 25%   -6.153733e-01 -6.153733e-01 -6.153733e-01 -6.947551e-01 -6.947551e-01
# 50%   -4.594074e-02 -4.594074e-02 -4.594074e-02  2.318848e-02  2.318848e-02
# 75%    6.658500e-01  6.658500e-01  6.658500e-01  5.975433e-01  5.975433e-01
# max    3.370655e+00  3.370655e+00  3.370655e+00  3.469318e+00  3.469318e+00
#
#        ...       WageEUR     LWBRating     RWBRating        Vision  \
# count  ...  7.344000e+03  7.344000e+03  7.344000e+03  7.344000e+03
# mean   ... -4.257064e-17 -1.238419e-16 -1.238419e-16 -5.418082e-17
# std    ...  1.000068e+00  1.000068e+00  1.000068e+00  1.000068e+00
# min    ... -4.522642e-01 -3.039917e+00 -3.039917e+00 -3.704642e+00
# 25%    ... -4.270994e-01 -6.520392e-01 -6.520392e-01 -7.170708e-01
# 50%    ... -3.264404e-01 -2.365015e-02 -2.365015e-02 -2.763140e-02
# 75%    ... -2.446334e-02  7.304166e-01  7.304166e-01  6.618080e-01
# max    ...  1.713790e+01  3.369650e+00  3.369650e+00  3.534472e+00
#
#           Dribbling     RBRating     LBRating     Composure   Positioning  \
# count  7.344000e+03  7344.000000  7344.000000  7.344000e+03  7.344000e+03
# mean  -2.476837e-16     0.000000     0.000000 -2.786442e-16 -3.096047e-16
# std    1.000068e+00     1.000068     1.000068  1.000068e+00  1.000068e+00
# min   -4.985088e+00    -2.903856    -2.903856 -2.797489e+00 -3.955772e+00
# 25%   -6.177281e-01    -0.667892    -0.667892 -6.872216e-01 -5.442186e-01
# 50%   -1.115033e-02     0.038202     0.038202  1.620083e-02 -1.116338e-02
# 75%    7.167430e-01     0.744296     0.744296  7.196232e-01  6.285029e-01
# max    3.143054e+00     3.333307     3.333307  3.231846e+00  3.826834e+00
#
#        ShootingTotal
# count   7.344000e+03
# mean    2.476837e-16
# std     1.000068e+00
# min    -3.324727e+00
# 25%    -6.882886e-01
# 50%     4.991428e-02
# 75%     6.826596e-01
# max     3.108183e+00
#
# [8 rows x 31 columns]

# %%
#checking the distribution of a random variable
sb.displot(c_norm2['LFRating'], bins = 15,kde = True)
plt.title('Distribution', fontsize = 20)
plt.ylabel('Count', fontsize = 18)
plt.xlabel('Bin', fontsize = 18)
plt.show()

# %% [markdown]
# #### Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(c_norm2.values)
c_norm3 = pd.DataFrame(scaler.transform(c_norm2.values))
c_norm3.columns = cm1.columns

#adding index 
i = pd.DataFrame(cm1.index)
c_normm = pd.concat([c_norm3, i], axis = 1)
c_norm4 = c_normm.set_index('index')
c_norm4.describe()
# Out:
#           ValueEUR     RMRating     LMRating     CAMRating      CMRating  \
# count  7344.000000  7344.000000  7344.000000  7.344000e+03  7.344000e+03
# mean      0.000000     0.000000     0.000000  3.096047e-17  2.322035e-17
# std       1.000068     1.000068     1.000068  1.000068e+00  1.000068e+00
# min      -0.406282    -3.043979    -3.043979 -2.935282e+00 -3.222554e+00
# 25%      -0.338161    -0.614931    -0.614931 -5.778758e-01 -6.257817e-01
# 50%      -0.270040    -0.007669    -0.007669  1.147566e-02  5.757950e-02
# 75%      -0.109026     0.599593     0.599593  6.008272e-01  6.042684e-01
# max      15.137720     3.787717     3.787717  3.694923e+00  3.611058e+00
#
#            RFRating      LFRating      CFRating      LWRating      RWRating  \
# count  7.344000e+03  7.344000e+03  7.344000e+03  7.344000e+03  7.344000e+03
# mean   3.096047e-17  3.096047e-17  3.096047e-17 -3.096047e-17 -3.096047e-17
# std    1.000068e+00  1.000068e+00  1.000068e+00  1.000068e+00  1.000068e+00
# min   -3.035462e+00 -3.035462e+00 -3.035462e+00 -3.135763e+00 -3.135763e+00
# 25%   -6.153733e-01 -6.153733e-01 -6.153733e-01 -6.947551e-01 -6.947551e-01
# 50%   -4.594074e-02 -4.594074e-02 -4.594074e-02  2.318848e-02  2.318848e-02
# 75%    6.658500e-01  6.658500e-01  6.658500e-01  5.975433e-01  5.975433e-01
# max    3.370655e+00  3.370655e+00  3.370655e+00  3.469318e+00  3.469318e+00
#
#        ...       WageEUR     LWBRating     RWBRating        Vision  \
# count  ...  7.344000e+03  7.344000e+03  7.344000e+03  7.344000e+03
# mean   ...  3.870058e-18  3.096047e-17  3.096047e-17 -5.418082e-17
# std    ...  1.000068e+00  1.000068e+00  1.000068e+00  1.000068e+00
# min    ... -4.522642e-01 -3.039917e+00 -3.039917e+00 -3.704642e+00
# 25%    ... -4.270994e-01 -6.520392e-01 -6.520392e-01 -7.170708e-01
# 50%    ... -3.264404e-01 -2.365015e-02 -2.365015e-02 -2.763140e-02
# 75%    ... -2.446334e-02  7.304166e-01  7.304166e-01  6.618080e-01
# max    ...  1.713790e+01  3.369650e+00  3.369650e+00  3.534472e+00
#
#          Dribbling     RBRating     LBRating     Composure   Positioning  \
# count  7344.000000  7344.000000  7344.000000  7.344000e+03  7.344000e+03
# mean      0.000000     0.000000     0.000000 -2.322035e-17  6.192094e-17
# std       1.000068     1.000068     1.000068  1.000068e+00  1.000068e+00
# min      -4.985088    -2.903856    -2.903856 -2.797489e+00 -3.955772e+00
# 25%      -0.617728    -0.667892    -0.667892 -6.872216e-01 -5.442186e-01
# 50%      -0.011150     0.038202     0.038202  1.620083e-02 -1.116338e-02
# 75%       0.716743     0.744296     0.744296  7.196232e-01  6.285029e-01
# max       3.143054     3.333307     3.333307  3.231846e+00  3.826834e+00
#
#        ShootingTotal
# count   7.344000e+03
# mean    3.096047e-17
# std     1.000068e+00
# min    -3.324727e+00
# 25%    -6.882886e-01
# 50%     4.991428e-02
# 75%     6.826596e-01
# max     3.108183e+00
#
# [8 rows x 31 columns]

# %% [markdown]
# ### Group 4

# %% [markdown]
# #### Mutual Information

# %%
#choosing the label and predictor
g4_x = g4.drop(columns = ['Overall', 'BestPosition'])
g4_y = g4[['Overall']]
#using mutual information score to asses importance of each column 
discrete_features = g4_x.dtypes == int
mi_scores = make_mi_scores(g4_x, g4_y, discrete_features)
mi_scores.head(60)
# Out:
# STRating            2.014310
# ValueEUR            1.655696
# RFRating            1.591489
# LFRating            1.591489
# CFRating            1.591489
# CAMRating           1.356857
# RMRating            1.193204
# LMRating            1.193204
# RWRating            1.182235
# LWRating            1.182235
# ReleaseClause       1.089825
# ShootingTotal       1.075156
# Potential           1.036680
# CMRating            0.951977
# BallControl         0.938365
# Positioning         0.923983
# BaseStats           0.831031
# Reactions           0.820605
# Finishing           0.818362
# TotalStats          0.814385
# DribblingTotal      0.697051
# ShortPassing        0.667665
# WageEUR             0.642271
# Composure           0.625521
# Dribbling           0.625060
# ShotPower           0.619619
# LongShots           0.593705
# Volleys             0.547375
# PassingTotal        0.532696
# CDMRating           0.510610
# RWBRating           0.450340
# LWBRating           0.450340
# RBRating            0.422455
# LBRating            0.422455
# Vision              0.409640
# Attack              0.367808
# Team_Overall        0.345192
# CBRating            0.341680
# Club                0.335102
# Midfield            0.323204
# Curve               0.295059
# HeadingAccuracy     0.294058
# Defence             0.293719
# League              0.283720
# LongPassing         0.277373
# Crossing            0.251967
# Penalties           0.248941
# GKRating            0.228875
# TransferBudget      0.220690
# Growth              0.208308
# FKAccuracy          0.196877
# SkillMoves          0.195183
# DefendingTotal      0.187000
# Stamina             0.186103
# Age                 0.184233
# IntReputation       0.165611
# Aggression          0.153752
# PhysicalityTotal    0.148841
# Nationality         0.130509
# Marking             0.115778
# Name: MI Scores, dtype: float64

# %%
#plotting the mi scores
plt.figure(dpi=70, figsize=(10, 30))
plot_mi_scores(mi_scores)

# %%
#selecting features with mi scores more than 0.5
m1_scores = pd.DataFrame(mi_scores).reset_index()
m2_scores = m1_scores.rename(columns = {'index' : 'feature'})
m3_score = m2_scores[m2_scores['MI Scores'] >= 0.5]
#selecting the features
g4_x1 = g4_x[m3_score.feature.unique()]
#checking on the correlation of our variables
g4_x1.corr()
# Out:
#                 STRating  ValueEUR  RFRating  LFRating  CFRating  CAMRating  \
# STRating        1.000000  0.557350  0.958104  0.958104  0.958104   0.925937
# ValueEUR        0.557350  1.000000  0.545884  0.545884  0.545884   0.548618
# RFRating        0.958104  0.545884  1.000000  1.000000  1.000000   0.989209
# LFRating        0.958104  0.545884  1.000000  1.000000  1.000000   0.989209
# CFRating        0.958104  0.545884  1.000000  1.000000  1.000000   0.989209
# CAMRating       0.925937  0.548618  0.989209  0.989209  0.989209   1.000000
# RMRating        0.892748  0.536451  0.971021  0.971021  0.971021   0.983400
# LMRating        0.892748  0.536451  0.971021  0.971021  0.971021   0.983400
# RWRating        0.889741  0.528344  0.973303  0.973303  0.973303   0.981797
# LWRating        0.889741  0.528344  0.973303  0.973303  0.973303   0.981797
# ReleaseClause   0.530982  0.983663  0.521789  0.521789  0.521789   0.525881
# ShootingTotal   0.943256  0.501340  0.902503  0.902503  0.902503   0.862558
# Potential       0.686095  0.514672  0.636203  0.636203  0.636203   0.622805
# CMRating        0.873909  0.505775  0.944516  0.944516  0.944516   0.962424
# BallControl     0.885245  0.498368  0.933751  0.933751  0.933751   0.927462
# Positioning     0.908767  0.481651  0.882485  0.882485  0.882485   0.845727
# BaseStats       0.866282  0.482782  0.918326  0.918326  0.918326   0.921727
# Reactions       0.868022  0.491550  0.865784  0.865784  0.865784   0.837671
# Finishing       0.904104  0.503711  0.839788  0.839788  0.839788   0.793424
# TotalStats      0.865526  0.481167  0.921855  0.921855  0.921855   0.927023
# DribblingTotal  0.814146  0.489022  0.918815  0.918815  0.918815   0.930604
# ShortPassing    0.816131  0.453553  0.880329  0.880329  0.880329   0.906400
# WageEUR         0.590550  0.838687  0.585791  0.585791  0.585791   0.586608
# Composure       0.802010  0.441346  0.824537  0.824537  0.824537   0.812653
# Dribbling       0.793288  0.468193  0.890085  0.890085  0.890085   0.898699
# ShotPower       0.836888  0.402025  0.794732  0.794732  0.794732   0.752940
# LongShots       0.804692  0.429502  0.822346  0.822346  0.822346   0.809254
# Volleys         0.793630  0.408992  0.773745  0.773745  0.773745   0.747436
# PassingTotal    0.740333  0.438703  0.858120  0.858120  0.858120   0.900905
# CDMRating       0.727683  0.403832  0.784080  0.784080  0.784080   0.803502
#
#                 RMRating  LMRating  RWRating  LWRating  ...  DribblingTotal  \
# STRating        0.892748  0.892748  0.889741  0.889741  ...        0.814146
# ValueEUR        0.536451  0.536451  0.528344  0.528344  ...        0.489022
# RFRating        0.971021  0.971021  0.973303  0.973303  ...        0.918815
# LFRating        0.971021  0.971021  0.973303  0.973303  ...        0.918815
# CFRating        0.971021  0.971021  0.973303  0.973303  ...        0.918815
# CAMRating       0.983400  0.983400  0.981797  0.981797  ...        0.930604
# RMRating        1.000000  1.000000  0.993197  0.993197  ...        0.938104
# LMRating        1.000000  1.000000  0.993197  0.993197  ...        0.938104
# RWRating        0.993197  0.993197  1.000000  1.000000  ...        0.954989
# LWRating        0.993197  0.993197  1.000000  1.000000  ...        0.954989
# ReleaseClause   0.515301  0.515301  0.507055  0.507055  ...        0.468791
# ShootingTotal   0.811380  0.811380  0.814785  0.814785  ...        0.730928
# Potential       0.602398  0.602398  0.606137  0.606137  ...        0.588154
# CMRating        0.949224  0.949224  0.934367  0.934367  ...        0.865444
# BallControl     0.903250  0.903250  0.910375  0.910375  ...        0.913958
# Positioning     0.798616  0.798616  0.795230  0.795230  ...        0.698472
# BaseStats       0.940027  0.940027  0.929049  0.929049  ...        0.851128
# Reactions       0.800181  0.800181  0.795646  0.795646  ...        0.714352
# Finishing       0.739834  0.739834  0.744276  0.744276  ...        0.662744
# TotalStats      0.931807  0.931807  0.921671  0.921671  ...        0.845216
# DribblingTotal  0.938104  0.938104  0.954989  0.954989  ...        1.000000
# ShortPassing    0.878563  0.878563  0.866394  0.866394  ...        0.797547
# WageEUR         0.571429  0.571429  0.564196  0.564196  ...        0.522892
# Composure       0.779135  0.779135  0.774849  0.774849  ...        0.702816
# Dribbling       0.907238  0.907238  0.922290  0.922290  ...        0.973414
# ShotPower       0.720411  0.720411  0.714486  0.714486  ...        0.639746
# LongShots       0.765895  0.765895  0.779160  0.779160  ...        0.713561
# Volleys         0.704813  0.704813  0.705062  0.705062  ...        0.641765
# PassingTotal    0.913607  0.913607  0.900092  0.900092  ...        0.825201
# CDMRating       0.802631  0.802631  0.776298  0.776298  ...        0.688343
#
#                 ShortPassing   WageEUR  Composure  Dribbling  ShotPower  \
# STRating            0.816131  0.590550   0.802010   0.793288   0.836888
# ValueEUR            0.453553  0.838687   0.441346   0.468193   0.402025
# RFRating            0.880329  0.585791   0.824537   0.890085   0.794732
# LFRating            0.880329  0.585791   0.824537   0.890085   0.794732
# CFRating            0.880329  0.585791   0.824537   0.890085   0.794732
# CAMRating           0.906400  0.586608   0.812653   0.898699   0.752940
# RMRating            0.878563  0.571429   0.779135   0.907238   0.720411
# LMRating            0.878563  0.571429   0.779135   0.907238   0.720411
# RWRating            0.866394  0.564196   0.774849   0.922290   0.714486
# LWRating            0.866394  0.564196   0.774849   0.922290   0.714486
# ReleaseClause       0.434095  0.820383   0.419474   0.448665   0.380673
# ShootingTotal       0.764172  0.540798   0.792671   0.714059   0.884378
# Potential           0.507341  0.499515   0.443980   0.578254   0.477980
# CMRating            0.923372  0.551680   0.815147   0.832205   0.742389
# BallControl         0.827100  0.540533   0.771762   0.874383   0.733185
# Positioning         0.750405  0.526007   0.815400   0.661562   0.756873
# BaseStats           0.827113  0.518149   0.763093   0.818308   0.744219
# Reactions           0.747160  0.538573   0.774246   0.669689   0.704813
# Finishing           0.679598  0.524958   0.717199   0.647765   0.752034
# TotalStats          0.842952  0.528218   0.804179   0.798115   0.767182
# DribblingTotal      0.797547  0.522892   0.702816   0.973414   0.639746
# ShortPassing        1.000000  0.493571   0.737207   0.774288   0.681679
# WageEUR             0.493571  1.000000   0.494894   0.499297   0.456759
# Composure           0.737207  0.494894   1.000000   0.665713   0.715358
# Dribbling           0.774288  0.499297   0.665713   1.000000   0.633239
# ShotPower           0.681679  0.456759   0.715358   0.633239   1.000000
# LongShots           0.735276  0.466668   0.706013   0.696556   0.748604
# Volleys             0.688068  0.451427   0.725600   0.618283   0.758748
# PassingTotal        0.904619  0.487716   0.735974   0.796327   0.652084
# CDMRating           0.800639  0.450509   0.717508   0.655829   0.659331
#
#                 LongShots   Volleys  PassingTotal  CDMRating
# STRating         0.804692  0.793630      0.740333   0.727683
# ValueEUR         0.429502  0.408992      0.438703   0.403832
# RFRating         0.822346  0.773745      0.858120   0.784080
# LFRating         0.822346  0.773745      0.858120   0.784080
# CFRating         0.822346  0.773745      0.858120   0.784080
# CAMRating        0.809254  0.747436      0.900905   0.803502
# RMRating         0.765895  0.704813      0.913607   0.802631
# LMRating         0.765895  0.704813      0.913607   0.802631
# RWRating         0.779160  0.705062      0.900092   0.776298
# LWRating         0.779160  0.705062      0.900092   0.776298
# ReleaseClause    0.413140  0.387630      0.423741   0.388506
# ShootingTotal    0.878363  0.838641      0.702262   0.677002
# Potential        0.479703  0.427601      0.425742   0.339766
# CMRating         0.794660  0.737611      0.942206   0.911182
# BallControl      0.749706  0.721658      0.800892   0.722997
# Positioning      0.732524  0.763386      0.682940   0.695799
# BaseStats        0.743373  0.693871      0.865995   0.903590
# Reactions        0.730310  0.734480      0.690030   0.712007
# Finishing        0.746289  0.745120      0.586780   0.572940
# TotalStats       0.785374  0.755338      0.896778   0.918257
# DribblingTotal   0.713561  0.641765      0.825201   0.688343
# ShortPassing     0.735276  0.688068      0.904619   0.800639
# WageEUR          0.466668  0.451427      0.487716   0.450509
# Composure        0.706013  0.725600      0.735974   0.717508
# Dribbling        0.696556  0.618283      0.796327   0.655829
# ShotPower        0.748604  0.758748      0.652084   0.659331
# LongShots        1.000000  0.728873      0.725017   0.653450
# Volleys          0.728873  1.000000      0.651747   0.630125
# PassingTotal     0.725017  0.651747      1.000000   0.841788
# CDMRating        0.653450  0.630125      0.841788   1.000000
#
# [30 rows x 30 columns]

# %% [markdown]
# #### Multicollinearity

# %%
#selecting the features
at1 = g4_x1.copy()

# set figure size
plt.figure(figsize=(10,7))

# Generate a mask to onlyshow the bottom triangle
mask = np.triu(np.ones_like(at1.corr(), dtype=bool))
# generate heatmap
sb.heatmap(at1.corr(), mask=mask, vmin=-1, vmax=1 ,cmap="YlGnBu", center = 0)
plt.title('Correlation Coefficient Of Predictors')
plt.show()

# %%
#plotting a cluster map
sb.clustermap(at1.corr(), figsize=(20,20), cmap = "YlGnBu")

# %%
#checking the vif scores for our data
y = compute_vif(at1)
at1.drop(columns = ['intercept'], inplace = True)
y
# Out:
#           Variable         VIF
# 0         STRating   59.290039
# 1         ValueEUR   35.190616
# 2         RFRating         inf
# 3         LFRating         inf
# 4         CFRating         inf
# 5        CAMRating  161.378512
# 6         RMRating         inf
# 7         LMRating         inf
# 8         RWRating         inf
# 9         LWRating         inf
# 10   ReleaseClause   31.536372
# 11   ShootingTotal  311.147764
# 12       Potential    3.011989
# 13        CMRating  131.929479
# 14     BallControl   18.987450
# 15     Positioning   13.269697
# 16       BaseStats   93.021764
# 17       Reactions    8.659540
# 18       Finishing   77.426792
# 19      TotalStats   95.707452
# 20  DribblingTotal  101.956066
# 21    ShortPassing   11.935453
# 22         WageEUR    3.748608
# 23       Composure    4.099005
# 24       Dribbling   36.872195
# 25       ShotPower   22.123259
# 26       LongShots   21.416485
# 27         Volleys    5.261894
# 28    PassingTotal   46.606862
# 29       CDMRating   43.278023

# %%
#describing our features
at1.describe()
# Out:
#           STRating      ValueEUR     RFRating     LFRating     CFRating  \
# count  3235.000000  3.235000e+03  3235.000000  3235.000000  3235.000000
# mean     66.834312  3.201683e+06    64.582380    64.582380    64.582380
# std       6.449346  9.401134e+06     6.828195     6.828195     6.828195
# min      47.000000  0.000000e+00    45.000000    45.000000    45.000000
# 25%      63.000000  5.500000e+05    60.000000    60.000000    60.000000
# 50%      67.000000  1.100000e+06    64.000000    64.000000    64.000000
# 75%      71.000000  2.100000e+06    69.000000    69.000000    69.000000
# max      92.000000  1.940000e+08    93.000000    93.000000    93.000000
#
#          CAMRating     RMRating     LMRating     RWRating     LWRating  ...  \
# count  3235.000000  3235.000000  3235.000000  3235.000000  3235.000000  ...
# mean     64.617002    64.139104    64.139104    63.581762    63.581762  ...
# std       6.973678     7.021863     7.021863     6.971297     6.971297  ...
# min      44.000000    44.000000    44.000000    43.000000    43.000000  ...
# 25%      60.000000    59.000000    59.000000    59.000000    59.000000  ...
# 50%      64.000000    64.000000    64.000000    63.000000    63.000000  ...
# 75%      69.000000    68.000000    68.000000    68.000000    68.000000  ...
# max      93.000000    93.000000    93.000000    92.000000    92.000000  ...
#
#        DribblingTotal  ShortPassing        WageEUR    Composure    Dribbling  \
# count     3235.000000   3235.000000    3235.000000  3235.000000  3235.000000
# mean        65.358887     60.102628   10516.120556    61.109119    64.941267
# std          7.391899      8.786408   24643.184933     9.789316     8.142303
# min         43.000000     28.000000     500.000000    32.000000    39.000000
# 25%         61.000000     55.000000    1000.000000    54.000000    60.000000
# 50%         65.000000     60.000000    3000.000000    61.000000    65.000000
# 75%         70.000000     66.000000   10000.000000    68.000000    70.000000
# max         95.000000     91.000000  350000.000000    96.000000    96.000000
#
#          ShotPower    LongShots      Volleys  PassingTotal    CDMRating
# count  3235.000000  3235.000000  3235.000000   3235.000000  3235.000000
# mean     67.442349    60.790417    59.063988     54.610510    48.595672
# std       8.486447     8.549574    10.393194      9.152444     7.491804
# min      38.000000    30.000000    27.000000     30.000000    29.000000
# 25%      62.000000    55.000000    52.000000     48.000000    43.000000
# 50%      68.000000    61.000000    59.000000     54.000000    48.000000
# 75%      73.000000    66.000000    66.000000     61.000000    53.000000
# max      94.000000    94.000000    90.000000     91.000000    77.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# #### Rescaling

# %%
# rescaling our features using minmax scaler 
a_norm = pd.DataFrame(scaler.fit_transform(at1.values))
a_norm.columns = at1.columns

#adding index 
i = pd.DataFrame(at1.index)
a_norm1 = pd.concat([a_norm, i], axis = 1)
a_norm2 = a_norm1.set_index('index')

#describing our rescaled dataframe 
a_norm2.describe()
# Out:
#            STRating      ValueEUR      RFRating      LFRating      CFRating  \
# count  3.235000e+03  3.235000e+03  3.235000e+03  3.235000e+03  3.235000e+03
# mean   1.124568e-15  1.757138e-17 -8.785691e-16 -8.785691e-16 -8.785691e-16
# std    1.000155e+00  1.000155e+00  1.000155e+00  1.000155e+00  1.000155e+00
# min   -3.075875e+00 -3.406162e-01 -2.868314e+00 -2.868314e+00 -2.868314e+00
# 25%   -5.946192e-01 -2.821035e-01 -6.712006e-01 -6.712006e-01 -6.712006e-01
# 50%    2.569461e-02 -2.235909e-01 -8.530370e-02 -8.530370e-02 -8.530370e-02
# 75%    6.460084e-01 -1.172043e-01  6.470675e-01  6.470675e-01  6.470675e-01
# max    3.902656e+00  2.029838e+01  4.162449e+00  4.162449e+00  4.162449e+00
#
#           CAMRating      RMRating      LMRating      RWRating      LWRating  \
# count  3.235000e+03  3.235000e+03  3.235000e+03  3.235000e+03  3.235000e+03
# mean  -7.731408e-16 -2.108566e-16 -2.108566e-16  3.514276e-17  3.514276e-17
# std    1.000155e+00  1.000155e+00  1.000155e+00  1.000155e+00  1.000155e+00
# min   -2.956860e+00 -2.868501e+00 -2.868501e+00 -2.952814e+00 -2.952814e+00
# 25%   -6.621636e-01 -7.319850e-01 -7.319850e-01 -6.573339e-01 -6.573339e-01
# 50%   -8.848946e-02 -1.981313e-02 -1.981313e-02 -8.346394e-02 -8.346394e-02
# 75%    6.286032e-01  5.499244e-01  5.499244e-01  6.338736e-01  6.338736e-01
# max    4.070648e+00  4.110784e+00  4.110784e+00  4.077094e+00  4.077094e+00
#
#        ...  DribblingTotal  ShortPassing       WageEUR     Composure  \
# count  ...     3235.000000  3.235000e+03  3.235000e+03  3.235000e+03
# mean   ...        0.000000  1.405711e-16 -3.514276e-17  2.108566e-16
# std    ...        1.000155  1.000155e+00  1.000155e+00  1.000155e+00
# min    ...       -3.025250 -3.654234e+00 -4.065087e-01 -2.974020e+00
# 25%    ...       -0.589775 -5.808308e-01 -3.862160e-01 -7.263243e-01
# 50%    ...       -0.048559 -1.168206e-02 -3.050451e-01 -1.114847e-02
# 75%    ...        0.627962  6.712964e-01 -2.094698e-02  7.040274e-01
# max    ...        4.010565  3.517040e+00  1.377810e+01  3.564731e+00
#
#           Dribbling     ShotPower     LongShots       Volleys  PassingTotal  \
# count  3.235000e+03  3.235000e+03  3.235000e+03  3.235000e+03  3.235000e+03
# mean  -7.379980e-16  5.622842e-16 -3.162849e-16 -3.162849e-16  2.108566e-16
# std    1.000155e+00  1.000155e+00  1.000155e+00  1.000155e+00  1.000155e+00
# min   -3.186479e+00 -3.469874e+00 -3.601955e+00 -3.085572e+00 -2.689371e+00
# 25%   -6.069574e-01 -6.413980e-01 -6.773803e-01 -6.797795e-01 -7.223788e-01
# 50%    7.214383e-03  6.572089e-02  2.451761e-02 -6.157638e-03 -6.671490e-02
# 75%    6.213862e-01  6.549867e-01  6.094325e-01  6.674642e-01  6.982263e-01
# max    3.815079e+00  3.129903e+00  3.884956e+00  2.977025e+00  3.976546e+00
#
#           CDMRating
# count  3.235000e+03
# mean  -2.108566e-16
# std    1.000155e+00
# min   -2.616019e+00
# 25%   -7.470213e-01
# 50%   -7.952216e-02
# 75%    5.879770e-01
# max    3.791973e+00
#
# [8 rows x 30 columns]

# %%
#checking the distribution of a random variable
sb.displot(a_norm2['Composure'], bins = 15,kde = True)
plt.title('Distribution', fontsize = 20)
plt.ylabel('Count', fontsize = 18)
plt.xlabel('Bin', fontsize = 18)
plt.show()

# %% [markdown]
# #### Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(a_norm2.values)
a_norm3 = pd.DataFrame(scaler.transform(a_norm2.values))
a_norm3.columns = at1.columns

#adding index 
i = pd.DataFrame(at1.index)
a_normm = pd.concat([a_norm3, i], axis = 1)
a_norm4 = a_normm.set_index('index')
a_norm4.describe()
# Out:
#            STRating      ValueEUR     RFRating     LFRating     CFRating  \
# count  3.235000e+03  3.235000e+03  3235.000000  3235.000000  3235.000000
# mean  -7.028553e-17 -1.757138e-17     0.000000     0.000000     0.000000
# std    1.000155e+00  1.000155e+00     1.000155     1.000155     1.000155
# min   -3.075875e+00 -3.406162e-01    -2.868314    -2.868314    -2.868314
# 25%   -5.946192e-01 -2.821035e-01    -0.671201    -0.671201    -0.671201
# 50%    2.569461e-02 -2.235909e-01    -0.085304    -0.085304    -0.085304
# 75%    6.460084e-01 -1.172043e-01     0.647067     0.647067     0.647067
# max    3.902656e+00  2.029838e+01     4.162449     4.162449     4.162449
#
#           CAMRating      RMRating      LMRating      RWRating      LWRating  \
# count  3.235000e+03  3.235000e+03  3.235000e+03  3.235000e+03  3.235000e+03
# mean   7.028553e-17  3.514276e-17  3.514276e-17  3.514276e-17  3.514276e-17
# std    1.000155e+00  1.000155e+00  1.000155e+00  1.000155e+00  1.000155e+00
# min   -2.956860e+00 -2.868501e+00 -2.868501e+00 -2.952814e+00 -2.952814e+00
# 25%   -6.621636e-01 -7.319850e-01 -7.319850e-01 -6.573339e-01 -6.573339e-01
# 50%   -8.848946e-02 -1.981313e-02 -1.981313e-02 -8.346394e-02 -8.346394e-02
# 75%    6.286032e-01  5.499244e-01  5.499244e-01  6.338736e-01  6.338736e-01
# max    4.070648e+00  4.110784e+00  4.110784e+00  4.077094e+00  4.077094e+00
#
#        ...  DribblingTotal  ShortPassing       WageEUR     Composure  \
# count  ...     3235.000000   3235.000000  3.235000e+03  3.235000e+03
# mean   ...        0.000000      0.000000  1.757138e-17 -3.514276e-17
# std    ...        1.000155      1.000155  1.000155e+00  1.000155e+00
# min    ...       -3.025250     -3.654234 -4.065087e-01 -2.974020e+00
# 25%    ...       -0.589775     -0.580831 -3.862160e-01 -7.263243e-01
# 50%    ...       -0.048559     -0.011682 -3.050451e-01 -1.114847e-02
# 75%    ...        0.627962      0.671296 -2.094698e-02  7.040274e-01
# max    ...        4.010565      3.517040  1.377810e+01  3.564731e+00
#
#           Dribbling     ShotPower     LongShots       Volleys  PassingTotal  \
# count  3.235000e+03  3.235000e+03  3.235000e+03  3.235000e+03   3235.000000
# mean  -3.514276e-17 -3.514276e-17 -3.514276e-17  3.514276e-17      0.000000
# std    1.000155e+00  1.000155e+00  1.000155e+00  1.000155e+00      1.000155
# min   -3.186479e+00 -3.469874e+00 -3.601955e+00 -3.085572e+00     -2.689371
# 25%   -6.069574e-01 -6.413980e-01 -6.773803e-01 -6.797795e-01     -0.722379
# 50%    7.214383e-03  6.572089e-02  2.451761e-02 -6.157638e-03     -0.066715
# 75%    6.213862e-01  6.549867e-01  6.094325e-01  6.674642e-01      0.698226
# max    3.815079e+00  3.129903e+00  3.884956e+00  2.977025e+00      3.976546
#
#          CDMRating
# count  3235.000000
# mean      0.000000
# std       1.000155
# min      -2.616019
# 25%      -0.747021
# 50%      -0.079522
# 75%       0.587977
# max       3.791973
#
# [8 rows x 30 columns]

# %%
#checking the distribution of a random variable
sb.displot(a_norm2['Composure'], bins = 15,kde = True)
plt.title('Distribution', fontsize = 20)
plt.ylabel('Count', fontsize = 18)
plt.xlabel('Bin', fontsize = 18)
plt.show()

# %% [markdown]
# ## 8. Modelling

# %% [markdown]
# Our data has been divided into 4 groups so as to maximize our algorithms learning from the models effectively we will train these groups independently.

# %% [markdown]
# ## a. Baseline models

# %% [markdown]
# The first step towards modelling will be creating our baseline modles these are models that will be used as refernce for the other models that we will create. Naturally the baseline models that we create will be simple linear regression models that can give us a glimpse of what we expect.
#
# The first machine learning algorithm that we will employ will be linear regression it uses the equation **y = mx + c** to predict y where m is the coeficient and c is the y intercept.

# %% [markdown]
# #### Group 1 (Goalkeepers)

# %%
#getting our label and predictor 
g1_y1 = g1_y.values.reshape(-1, 1)
#selecting one predictors
gk = g_norm4.values

#splitting our data into 80% train and 20% test
from sklearn.model_selection import train_test_split
r_train, r_test, o_train, o_test = train_test_split(gk, g1_y1, test_size = 0.2, random_state = 0)

#training
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
lr = LinearRegression()
parameters = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
grid = GridSearchCV(lr, parameters, cv=5)
grid.fit(r_train, o_train)

#predicting
o_pred = grid.predict(r_test).round(2)

# %% [markdown]
# ##### Model evaluation

# %%
#we will create a comparison frame
frame = pd.DataFrame({'Actual': o_test.flatten(), 'Predicted': o_pred.flatten()})
frame.describe()
# Out:
#            Actual   Predicted
# count  423.000000  423.000000
# mean    64.654846   64.670709
# std      7.547575    7.543651
# min     48.000000   48.130000
# 25%     60.000000   59.895000
# 50%     64.000000   64.230000
# 75%     70.000000   69.665000
# max     90.000000   90.230000

# %%
from sklearn import metrics
#checking on the root mean squared of our data
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(o_test, o_pred)).round(4))  

#getting the r squared of the data 
print ('The coefficient of determination is: ', metrics.r2_score(o_test, o_pred).round(4))
# Out:
# Root Mean Squared Error: 0.228
# The coefficient of determination is:  0.9991

# %% [markdown]
# We have achieved an RMSE score of 0.228 and achieved an R-Squared of 0.9991 for the first model we will exect the rest of the models to perform better.

# %% [markdown]
# #### Group 2 (Defenders)

# %%
#getting our label and predictor 
g2_y1 = g2_y.values.reshape(-1, 1)
#selecting one predictors
df = d_norm4.values

#splitting our data into 80% train and 20% test
r1_train, r1_test, o1_train, o1_test = train_test_split(df, g2_y1, test_size = 0.2, random_state = 0)

#training
lr = LinearRegression()
parameters = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
grid = GridSearchCV(lr, parameters, cv=5)
grid.fit(r1_train, o1_train)

#predicting
o1_pred = pd.DataFrame(grid.predict(r1_test).round(5))
o1_test1 = pd.DataFrame(o1_test)

# %% [markdown]
# ##### Model evaluation

# %%
#we will create a comparison frame
o1_pred.columns = ['predicted']
o1_test1.columns = ['true']
frame = pd.concat([o1_test1, o1_pred])
frame.describe()
# Out:
#               true    predicted
# count  1293.000000  1293.000000
# mean     65.826759    65.774819
# std       6.452085     6.361842
# min      48.000000    47.561240
# 25%      62.000000    61.635160
# 50%      66.000000    65.391290
# 75%      70.000000    69.829070
# max      86.000000    86.836820

# %%
#checking on the root mean squared of our data
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(o1_test, o1_pred)).round(5))  

#getting the r squared of the data 
print ('The coefficient of determination is: ', metrics.r2_score(o1_test, o1_pred).round(5))
# Out:
# Root Mean Squared Error: 1.16256
# The coefficient of determination is:  0.96751

# %% [markdown]
# The model for the defenders has achieved an RMSE score of 1.1626 and an R-squared of 0,9675 these are the scores for the succeeding models to beat.

# %% [markdown]
# #### Group 3 (Midfielders)

# %%
#getting our label and predictor 
g3_y1 = g3_y.values.reshape(-1, 1)
#selecting one predictors
cm = c_norm4.values

#splitting our data into 80% train and 20% test
r2_train, r2_test, o2_train, o2_test = train_test_split(cm, g3_y1, test_size = 0.2, random_state = 0)

#training
parameters = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
grid = GridSearchCV(lr, parameters, cv=5)
grid.fit(r2_train, o2_train)

#predicting
o2_pred = grid.predict(r2_test).round(5)

# %% [markdown]
# ##### Model evaluation

# %%
#we will create a comparison frame
frame = pd.DataFrame({'Actual': o2_test.flatten(), 'Predicted': o2_pred.flatten()})
frame.describe()
# Out:
#             Actual    Predicted
# count  1469.000000  1469.000000
# mean     66.085773    66.115418
# std       6.877440     6.699985
# min      48.000000    48.236870
# 25%      62.000000    61.732550
# 50%      66.000000    65.736650
# 75%      71.000000    70.492010
# max      87.000000    89.030780

# %%
#checking on the root mean squared of our data
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(o2_test, o2_pred)).round(4))  

#getting the r squared of the data 
print ('The coefficient of determination is: ', metrics.r2_score(o2_test, o2_pred).round(4))
# Out:
# Root Mean Squared Error: 1.7161
# The coefficient of determination is:  0.9377

# %% [markdown]
# The baseline model for midfialders has achieved an RMSE score of 1.7214 and an R-squared of 0.9373 these are the scores for the succeeding models to beat.

# %% [markdown]
# #### Group 4 (Attackers)

# %%
#getting our label and predictor 
g4_y1 = g4_y.values.reshape(-1, 1)
#selecting one predictors
att = a_norm4.values

#splitting our data into 80% train and 20% test
r3_train, r3_test, o3_train, o3_test = train_test_split(att, g4_y1, test_size = 0.2, random_state = 0)

#training
parameters = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
grid = GridSearchCV(lr, parameters, cv=5)
grid.fit(r3_train, o3_train)

#predicting
o3_pred = grid.predict(r3_test).round(5)

# %% [markdown]
# ##### Model Evaluation

# %%
#we will create a comparison frame
frame = pd.DataFrame({'Actual': o3_test.flatten(), 'Predicted': o3_pred.flatten()})
frame.describe()
# Out:
#            Actual   Predicted
# count  647.000000  647.000000
# mean    65.765070   65.773296
# std      6.867644    6.761422
# min     48.000000   47.458570
# 25%     61.500000   61.527135
# 50%     66.000000   65.884460
# 75%     70.000000   70.194470
# max     88.000000   88.091360

# %%
#checking on the root mean squared of our data
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(o3_test, o3_pred)).round(4))  

#getting the r squared of the data 
print ('The coefficient of determination is: ', metrics.r2_score(o3_test, o3_pred).round(4))
# Out:
# Root Mean Squared Error: 0.8916
# The coefficient of determination is:  0.9831

# %% [markdown]
# The baseline model for the attackers has achieved an RMSE score of 0.8923 and an R-squared of 0.9831 these are the scores for the succeeding models to beat.

# %% [markdown]
# ## b. Ridge Regression
#
# * Overfitting, which leads to excessively complex models which leads to noise is a challenge in some machine learning algorithms such as linear regression and polynomial regression, however we can avoid this problem by applying regularization to multi linear regression models.
#
# * Regularization aims to alleviate this phenomenon by constraining bias hence promoting simple solutions regularization is done by adding a penalty a penalty parameter that is equivalent to the square of the magnitude of the coeffiicients as shown.
# > **Loss function = OLS + alpha * sum (squared coefficients)**
#
# > Where alpha is the parameter we need to select
#
# * A low alpha value will lead to overfitting while a high alpha value will lead to underfitting.
#
# * Ridge regression implements the L2 regularization by addng a penalty equal to the sum of the absolute value of the coefficients.

# %% [markdown]
# #### Group 1 (Goalkeepers)

# %%
#splitting the data 
r_train, r_test, o_train, o_test = train_test_split(gk, g1_y1, test_size = 0.2, random_state = 0)
#importing modules
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# From our data the maximum value available in the data is 17.7 while the minimum value that is in our data is -3.8 for our logspace we are going to set this as our maximum and minimum values and for it to return 10 values.

# %%
#instantiate
ridge = Ridge()
search  = GridSearchCV(estimator = ridge, param_grid = {'alpha' : np.logspace(-4, 18, 10)}, scoring = 'neg_mean_squared_error', refit = True, cv = 10)
search.fit(r_train, o_train)
#searching for the best alpha value
print ('Best alpha value: ', search.best_params_)

#searching for the best RMSE value 
print ('Best RMSE score of the data: ', abs(search.best_score_))
#we can confirm the above information based on the values given 
o_pred = search.predict(r_test)
#checking on the root mean squared of our data
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(o_test, o_pred)).round(4))  

#getting the r squared of the data 
print ('The coefficient of determination is: ', metrics.r2_score(o_test, o_pred).round(4))
# Out:
# Best alpha value:  {'alpha': 0.02782559402207126}
# Best RMSE score of the data:  0.058233885605751254
# Root Mean Squared Error: 0.2281
# The coefficient of determination is:  0.9991

# %% [markdown]
# #### Group 2 (Defenders)

# %%
#splitting our data into 80% train and 20% test
r1_train, r1_test, o1_train, o1_test = train_test_split(df, g2_y1, test_size = 0.2, random_state = 0)

# %% [markdown]
# From our data the maximum value in the data is 18.0 while the minimum value that is in our data is -4.3 for our logspace we are going to set this as our maximum and minimum values and for it to return 10 values.

# %%
search  = GridSearchCV(estimator = ridge, param_grid = {'alpha' : np.logspace(-4, 18, 10)}, scoring = 'neg_mean_squared_error', refit = True, cv = 10)
search.fit(r1_train, o1_train)
#searching for the best alpha value
print ('Best alpha value: ', search.best_params_)

#searching for the best RMSE value
print ('Best RMSE score of the data: ', abs(search.best_score_))
#we can confirm the above information based on the values given 
o1_pred = search.predict(r1_test)
#checking on the root mean squared of our data
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(o1_test, o1_pred)).round(4))  

#getting the r squared of the data 
print ('The coefficient of determination is: ', metrics.r2_score(o1_test, o1_pred).round(4))
# Out:
# Best alpha value:  {'alpha': 0.02782559402207126}
# Best RMSE score of the data:  1.3535271374914792
# Root Mean Squared Error: 1.1626
# The coefficient of determination is:  0.9675

# %% [markdown]
# #### Group 3 (Midfielders)

# %%
#splitting our data into 80% train and 20% test
r2_train, r2_test, o2_train, o2_test = train_test_split(cm, g3_y1, test_size = 0.2, random_state = 0)
cm.max()
# Out:
# 17.137900746681236

# %% [markdown]
# From our data the maximum value available in the data is 17.1 while the minimum value that is in our data is -4.8 for our logspace we are going to set this as our maximum and minimum values and for it to return 10 values.

# %%
#instantiate
ridge = Ridge()
search  = GridSearchCV(estimator = ridge, param_grid = {'alpha' : np.logspace(-5, 18, 10)}, scoring = 'neg_mean_squared_error', refit = True, cv = 10)
search.fit(r2_train, o2_train)
#searching for the best alpha value
print ('Best alpha value: ', search.best_params_)

#searching for the best RMSE value 
print ('Best RMSE score of the data: ', abs(search.best_score_))
#we can confirm the above information based on the values given 
o2_pred = search.predict(r2_test)
#checking on the root mean squared of our data
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(o2_test, o2_pred)).round(4))  

#getting the r squared of the data 
print ('The coefficient of determination is: ', metrics.r2_score(o2_test, o2_pred).round(4))
# Out:
# Best alpha value:  {'alpha': 1.2915496650148828}
# Best RMSE score of the data:  2.7821849198916313
# Root Mean Squared Error: 1.7169
# The coefficient of determination is:  0.9376

# %% [markdown]
# #### Group 4 (Attackers)

# %%
#splitting our data into 80% train and 20% test
r3_train, r3_test, o3_train, o3_test = train_test_split(att, g4_y1, test_size = 0.2, random_state = 0)

# %% [markdown]
# From our data the maximum value available in the data is 20.8 while the minimum value that is in our data is -4.4 for our logspace we are going to set this as our maximum and minimum values and for it to return 10 values

# %%
search  = GridSearchCV(estimator = ridge, param_grid = {'alpha' : np.logspace(-5, 21, 10)}, scoring = 'neg_mean_squared_error', refit = True, cv = 10)
search.fit(r3_train, o3_train)
#searching for the best alpha value
print ('Best alpha value: ', search.best_params_)

#searching for the best RMSE value 
print ('Best RMSE score of the data: ', abs(search.best_score_))

#we can confirm the above information based on the values given 
o3_pred = search.predict(r3_test)

#checking on the root mean squared of our data
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(o3_test, o3_pred)).round(4))  

#getting the r squared of the data 
print ('The coefficient of determination is: ', metrics.r2_score(o3_test, o3_pred).round(4))
# Out:
# Best alpha value:  {'alpha': 0.007742636826811269}
# Best RMSE score of the data:  0.9023217066114861
# Root Mean Squared Error: 0.8916
# The coefficient of determination is:  0.9831

# %%
ridge = Ridge(normalize = True,alpha = search.best_params_.get('alpha'))
ridge.fit(r3_train , o3_train)
o3_pred=ridge.predict(r3_test)
#checking on the root mean squared of our data
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(o3_test, o3_pred)).round(4))  

#getting the r squared of the data 
print ('The coefficient of determination is: ', metrics.r2_score(o3_test, o3_pred).round(4))
# Out:
# Root Mean Squared Error: 0.8947
# The coefficient of determination is:  0.983
